# %%
import pickle
wikidata_candidates_per_name= pickle.load(open('wikidata_candidates_per_name.p','rb'))

# %%
import pandas as pd

df_graph = pd.read_csv('/ivi/ilps/personal/vprovat/valkema_graph_directed_final_final.tsv',sep='\t')

# %%
import numpy as np
df_graph['candidates1'] = df_graph['person1'].map(lambda x: wikidata_candidates_per_name[x]
                                                 if x in wikidata_candidates_per_name and wikidata_candidates_per_name[x]!=[]
                                                  else np.nan)
df_graph['candidates2'] = df_graph['person2'].map(lambda x: wikidata_candidates_per_name[x]
                                                 if x in wikidata_candidates_per_name and wikidata_candidates_per_name[x]!=[]
                                                  else np.nan)
df_graph_wiki= df_graph[~(df_graph['candidates1'].isnull()) &~(df_graph['candidates2'].isnull())]
df_graph_wiki.head()
# Out:
#     person1         person2  \
# 2      Haan           Spier
# 311    Berg  Sybren Valkema
# 314    Berg     Wim Crouwel
# 318    Arts            Berg
# 322    Berg           Liang
#
#                                           document_ids  \
# 2    ['0001246757-0001246758-0001246759-0001246760-...
# 311  ['0001246763-0001246764-0001246765-0001246766-...
# 314  ['0001246763-0001246764-0001246765-0001246766-...
# 318  ['0001246763-0001246764-0001246765-0001246766-...
# 322  ['0001246763-0001246764-0001246765-0001246766-...
#
#                                            candidates1  \
# 2    [http://www.wikidata.org/entity/Q86819494, htt...
# 311  [http://www.wikidata.org/entity/Q123450260, ht...
# 314  [http://www.wikidata.org/entity/Q123450260, ht...
# 318        [http://www.wikidata.org/entity/Q110168132]
# 322  [http://www.wikidata.org/entity/Q123450260, ht...
#
#                                            candidates2
# 2          [http://www.wikidata.org/entity/Q105457909]
# 311  [http://www.wikidata.org/entity/Q2618110, http...
# 314  [http://www.wikidata.org/entity/Q555389, http:...
# 318  [http://www.wikidata.org/entity/Q123450260, ht...
# 322         [http://www.wikidata.org/entity/Q45441271]

# %%
### Try text similarity

# %%
from sentence_transformers import SentenceTransformer, util

# Load SBERT model
model = SentenceTransformer('sentence-transformers/paraphrase-xlm-r-multilingual-v1')

# %%
import requests
from functools import lru_cache

@lru_cache(maxsize=1000)  # Cache up to 1000 results
def fetch_wikidata_entity(entity_id):
    url = f"https://www.wikidata.org/w/api.php?action=wbgetentities&ids={entity_id}&format=json&props=descriptions|claims"
    response = requests.get(url)
    response.raise_for_status()  # Raise an HTTPError for bad responses
    return response.json()

@lru_cache(maxsize=1000)  # Cache up to 1000 results
def fetch_profession_labels(profession_ids, language='en'):
    ids = "|".join(profession_ids)
    url = f"https://www.wikidata.org/w/api.php?action=wbgetentities&ids={ids}&format=json&props=labels"
    response = requests.get(url)
    response.raise_for_status()  # Raise an HTTPError for bad responses
    return response.json()

def get_wikidata_info(entity_id, language='en'):
    data = fetch_wikidata_entity(entity_id)

    if entity_id not in data['entities']:
        return 'Entity not found.'

    entity_data = data['entities'][entity_id]

    # Get the description in the specified language
    description = entity_data.get('descriptions', {}).get(language, {}).get('value', 'Description not found.')

    # Get the profession (occupation) - Property P106
    claims = entity_data.get('claims', {})
    professions = []
    if 'P106' in claims:
        for profession_claim in claims['P106']:
            if 'mainsnak' in profession_claim and 'datavalue' in profession_claim['mainsnak']:
                profession_id = profession_claim['mainsnak']['datavalue']['value']['id']
                professions.append(profession_id)

    # Fetch the labels for the professions
    if professions:
        profession_data = fetch_profession_labels(tuple(professions), language)  # Use tuple for caching
        labels = []
        for pid in professions:
            label = profession_data['entities'][pid]['labels'].get(language, {}).get('value', 'Unknown profession')
            labels.append(label)
        professions = labels

    return description, ', '.join(professions)

# Example usage with Wikidata ID
entity_id = 'Q2618110'  # Sybren
description, professions = get_wikidata_info(entity_id)
print(f"Description: {description}")
print(f"Professions: {professions}")
# Out:
# Description: Dutch glass artist (1916-1996)
# Professions: glass artist, ceramicist, textile artist

# %%
Valkema_qid = 'Q2618110'
Valkema_description, Valkema_professions = get_wikidata_info(Valkema_qid)
Valkema_description_embedding = model.encode([Valkema_description], convert_to_tensor=True)[0]
Valkema_profession_embedding = model.encode([Valkema_professions], convert_to_tensor=True)[0]

# %%
def disambiguate(name):
    qids = [link.split('/')[-1] for link in wikidata_candidates_per_name[name]]
#     descriptions_and_professions = [get_wikidata_info(qid) for qid in qids]
    descriptions, professions = zip(*[get_wikidata_info(qid) for qid in qids])

    description_embeddings = model.encode(list(descriptions), convert_to_tensor=True)
    profession_embeddings = model.encode(list(professions), convert_to_tensor=True)
    
    similarity_scores_descriptions = np.array([util.pytorch_cos_sim(embedding, Valkema_description_embedding).item()
                                         for embedding in description_embeddings])
    similarity_scores_professions = np.array([util.pytorch_cos_sim(embedding, Valkema_profession_embedding).item()
                                         for embedding in profession_embeddings])
    
    similarity_scores = (similarity_scores_descriptions+similarity_scores_professions)/2
    best_ind = np.argmax(similarity_scores)
    
#     print(descriptions, professions, similarity_scores) # todo remove
    return qids[best_ind], descriptions[best_ind]

# %%
# Valkema_description
# Out:
# 'Dutch glass artist (1916-1996)'

# %%
disambiguate('Wim Crouwel')
# Out:
# ('Dutch graphic designer, type designer, and typographer', 'Dutch baseball player') ('type designer, graphic designer, postage stamp designer, university teacher, designer, typographer, drawer, costume designer', 'baseball player') [0.53427383 0.32968343]
# ('Q555389', 'Dutch graphic designer, type designer, and typographer')

# %%
wiki_people = set(df_graph_wiki['person1'].tolist()+df_graph_wiki['person1'].tolist())
wiki_people_fullnames = [person for person in wiki_people if person.count(' ')>0] # only names longer than 1 word

wiki_people_fullnames
# Out:
# ['John Schlesinger',
#  'Yvonne Brunhammer',
#  'Dorothy Miller',
#  'Alice Rooney',
#  'Joey Kirkpatrick',
#  'Richard Price',
#  'Kim MacConnel',
#  'Thomas McEvilley',
#  'Kenneth M. Wilson',
#  'Rudy Autio',
#  'Leendert van der Linden',
#  'Kees Slegt',
#  'Gerrit Komrij',
#  'Mary Shaffer',
#  'H. Bakker',
#  'Dan Hogan',
#  'Patrick Reyntiens',
#  'Piet Calis',
#  'Adriek Westenenk',
#  'David Van Arsdale',
#  'Gerard Cox',
#  'Anton Philips',
#  'Seth Gaaikema',
#  'Nicolas Morin',
#  'Anne Gould',
#  'Roberto Niederer',
#  'Wim Brusse',
#  'Paul Gardner',
#  'Nick Mount',
#  'Isabelle Monod',
#  'Henry Miller',
#  'Frank van den Ham',
#  'George Ravenscroft',
#  'Heikki Kallio',
#  'Zamira Jonker',
#  'Charles Johnson',
#  'Jim Melchert',
#  'Claude Bernard',
#  'Lambert van Meerten',
#  'Marijke Linthorst',
#  'Mitchell Wolfson, Jr.',
#  'Michael Brown',
#  'John Cook',
#  'Mark Rosenbaum',
#  'Charles Cowles',
#  'Harry Turner',
#  'Ruth Allen',
#  'Margit Kocsis',
#  'George Rochester',
#  'Seaver Leslie',
#  'Chris Steenbergen',
#  'Gerard van Westerloo',
#  'Jan Rot',
#  'Susan Hammond',
#  'Pike Powers',
#  'LaMar Harrington',
#  'Frank Kooman',
#  'Claudia Fitch',
#  'John Upham',
#  'Ineke Kanters',
#  'Kim Levin',
#  'William G. Hoover',
#  'Jeff Todd',
#  'Dorothé van Agthoven',
#  'Maria Westra',
#  'Benny Motzfeldt',
#  'Gio Colucci',
#  'Durk Valkema',
#  'Roger Dutilleul',
#  'Tchai Munch',
#  'Marsha Burns',
#  'Floris Meydam',
#  'Henk Dijk',
#  'Donald Davis',
#  'David Hepp',
#  'Albinas Elskus',
#  'Fred Leach',
#  'Kaj Franck',
#  'Simon Pierce',
#  'John Bennett',
#  'Cheryl Smith',
#  'Bert Vos',
#  'Els van Westerloo',
#  'Robin Winter',
#  'John Simpson',
#  'Ed Carpenter',
#  'Miroslav Vondra',
#  'Adriaan Veen',
#  'Andy Warhol',
#  'Erich Herzog',
#  'Barbara Mayer',
#  'Willem Heesen',
#  'Ruben Nunes',
#  'Shane Fero',
#  'Hanneke Fokkelman',
#  'Robert Coleman',
#  'Gerard Blaauw',
#  'Sheila Klein',
#  'Paul Soldner',
#  'Philippe Barde',
#  'Sarah Miles',
#  'Jean-Pierre Melville',
#  'Joost van Santen',
#  'Hans Dieter Rommeney',
#  'Paul Cunningham',
#  'Marianne Maderna',
#  'Jana Paroubek',
#  'Lloyd Gibson',
#  'Paul Friedlander',
#  'Terence Stamp',
#  'Robert Willson',
#  'William Welby',
#  'Bernard Heesen',
#  'A. F. Gangkofner',
#  'Fernand Lacaf',
#  'Cyril Julian',
#  'Margaret Ballantyne',
#  'Gerard Schwarz',
#  'Pat Steir',
#  'Lino Tagliapietra',
#  'Hans Sleutelaar',
#  'Susan Plum',
#  'Peter Rath',
#  'Josef Emil Schneckendorf',
#  'Susan Sontag',
#  'J. Stewart Johnson',
#  'Frantz Kinnen',
#  'Serge Korber',
#  'Nancy Lee',
#  'Hasse Holmerud',
#  'Phillip Jacobson',
#  'Judy Moran',
#  'Mary White',
#  'Donald Holden',
#  'Louis Leloup',
#  'Bill White',
#  'Dirk Hubers',
#  'Esther Stasse',
#  'Tom Wesselmann',
#  'Kate Vogel',
#  'Richard Cohen',
#  'René Smeets',
#  'Richard Harned',
#  'Marian Batavier',
#  'Josephine Schaper',
#  'Henk Verberkmoes',
#  'Joel Myers',
#  'Julia Kristeva',
#  'Nanne Ottema',
#  'Michael Glancy',
#  'Oscar Wilde',
#  'Stef Hagemeier',
#  'Angela van der Burght',
#  'Paulus Potter',
#  'Ulla Forsell',
#  'Richard Serra',
#  'Rob du Mée',
#  'Peter Stanley',
#  'William Morris',
#  'William Fine',
#  'Bert Frijns',
#  'Annika Anderson',
#  'Jef Diederen',
#  'Dirk Vis',
#  'Klaus Moje',
#  'Tom McGlauchlin',
#  'Nancy Sinatra',
#  'Rachel Carson',
#  'Hans Cossy',
#  'Arie Bijl',
#  'Bonnie Biggs',
#  'Gordon Cooper',
#  'Max Verboeket',
#  'Joep Nicolas',
#  'Lloyd E. Herman',
#  'Rick Beck',
#  'Clement Greenberg',
#  'Olaf Stevens',
#  'Tony Hanning',
#  'Hanns Model',
#  'John Leighton',
#  'Jan Blokker',
#  'Jim Cook',
#  'Andries Copier',
#  'Susan McLeod',
#  'Carolyn Adams',
#  'Fritz Dreisbach',
#  'David Huchthausen',
#  'Helena Gibson',
#  'Ann Welch',
#  'William Rosen',
#  'Alfred Kossmann',
#  'Anne van der Waerden',
#  'Robert Dane',
#  'Jean Masurel',
#  'Toots Zynsky',
#  'Joe Hawley',
#  'Pauline Solven',
#  'Rob Nieuwenhuys',
#  'Louis Sclafani',
#  'Paul de Lussanet',
#  'Michael Jaross',
#  'Otto Doppelfeld',
#  'Rita Tushingham',
#  'Stephen Snyder',
#  'Michael Hayton',
#  'Wilke Adolfsson',
#  'John Littleton',
#  'Buster Simpson',
#  'Carol Cohen',
#  'Jan van Wessum',
#  'Jet Sielcken',
#  'Richard Rathbone',
#  'Han Hu',
#  'Indra Kamadjojo',
#  'Jean Boyer',
#  'Trude Guermonprez',
#  'Dick Weiss',
#  'Herb Babcock',
#  'Ans Hey',
#  'Rebecca Stevens',
#  'Jean Sala',
#  'Gerrit Borgers',
#  'Fernando Ramirez',
#  'Tim Shaw',
#  'Antoon Derkinderen',
#  'Georg Jensen',
#  'Jean Despres',
#  'Philippe Hardy',
#  'Fred Bassetti',
#  'Horst Kerstan',
#  'Elisabeth Fritsch',
#  'Richard Kaplan',
#  'Frank den Oudsten',
#  'David Feldman',
#  'Narcissus Quagliata',
#  'Konrad Habermeier',
#  'Mart van Schijndel',
#  'John Pfeiffer',
#  'Alan Warhurst',
#  'Beb Vuyk',
#  'René Larsen',
#  'Theo Swagemakers',
#  'René van Ast',
#  'Charles Eyck',
#  'Robert Braun',
#  'Anne Gould Hauberg',
#  'Kyohei Fujita',
#  'David Kaplan',
#  'Don Reitz',
#  'Peter Will',
#  'Robert Kehlmann',
#  'Pavel Molnar',
#  'David Schwarz',
#  'Jan Dijker',
#  'Tiede Herrema',
#  'Norma Chapman',
#  'Erich Abel',
#  'Allard Pierson',
#  'Le Corbusier',
#  'Jack Schmidt',
#  'Renée Ridgway',
#  'Margo Leavin',
#  'Theun de Vries',
#  'Jeffrey Brotman',
#  'Marius Richters',
#  'Ann Gardner',
#  'Peter Aldridge',
#  'Jon Clark',
#  'Joanna Brom',
#  'Louis Mériaux',
#  'Barbara Weinstein',
#  'Frans Willebrands',
#  'H. Wilde',
#  'Johan van Loon',
#  'Richard La Londe',
#  'Boris Smirnov',
#  'Martin de Wit',
#  'Gianni Toso',
#  'Diane Katsiaficas',
#  'Anne-Marie Bertrand',
#  'William Warmus',
#  'Howard Stern',
#  'Erica de Ruiter',
#  'Miloslav Veverka',
#  'Eric Dolphy',
#  'Patrick Wadley',
#  'Brian Sefton',
#  'Jos Rovers',
#  'Janet Anderson',
#  'Marc Meyers',
#  'Thomas Griffith',
#  'Ivo de Wijs',
#  'Andrea Hagen',
#  'Niek Zwartjes',
#  'Donald Black',
#  'van der Linden',
#  'Howard Johnson',
#  'Oscar Paul',
#  'Charles Jongejans',
#  'Flora Mace',
#  'Robert Thurston',
#  'Jerry Pethick',
#  'Frances Senska',
#  'Martijn Wegman',
#  'Howard Schultz',
#  'Robert Siegel',
#  'De Sade',
#  'George L. Davis',
#  'Dale Chihuly',
#  'Gordon Rogers',
#  'John Torreano',
#  'Robert J. Block',
#  'Hans Albert Peters',
#  'Christiane Sellner',
#  'Erna van Osselen',
#  'Jean-Jacques Etchevery',
#  'Hans Dekker',
#  'Herman Melville',
#  'John Hylton',
#  'S. van Dijk',
#  'Claude Bleynie',
#  'David Niven',
#  'Jan-Erik Ritzman',
#  'Terry Thomas',
#  'Philip Pearce',
#  'Galileo Galilei',
#  'Tom Anderson',
#  'Peter Giele',
#  'Fons Bemelmans',
#  'W. Sahm',
#  'J. de Kleyn',
#  'Erwin Eisch',
#  'Bob Bergh',
#  'Frank van Helfteren',
#  'Guido de Waart',
#  'Paul Arthur Dufour',
#  'Marianne Stern',
#  'Sandra Shannonhouse',
#  'Roman Bartkiw',
#  'Donald Robertson',
#  'Dick Bush',
#  'Barbara Vaessen',
#  'Helen Turner',
#  'Ricky Bernstein',
#  'Douglas Anderson',
#  'Paul Bromberg',
#  'Krijn Giezen',
#  'David McLellan',
#  'Tony Jojola',
#  'Klaus Zimmer',
#  'Alvin Lustig',
#  'David Palterer',
#  'Laura Donefer',
#  'G. Scholten',
#  'Don G. Abel',
#  'Arend Roosenschoon',
#  'Paul Schneider',
#  'Richter Roegholt',
#  'Ann Simons',
#  'John Nygren',
#  'Margon Lindberg',
#  'William Carlson',
#  'Eileen Lewenstein',
#  'Richard P. Cooley',
#  'George S. McKearin',
#  'Dominick Labino',
#  'Carla Koch',
#  'Sally Reeve',
#  'Robbie Miller',
#  'Irvin J. Borowsky',
#  'James Watt',
#  'Jacques Lenoble',
#  'Gary Beecham',
#  'Elly Wouters',
#  'Glenys Barton',
#  'M. Lee',
#  'Simon Franke',
#  'Richard Soyer',
#  'Robin Welch',
#  'Wilhelm Kreis',
#  'Jean Paul Vroom',
#  'Archie Bray',
#  'Bernardine de Neeve',
#  'Janine Joly',
#  'Stephen Dee Edwards',
#  'Ted Nash',
#  'Donavon Boutz',
#  'Han Knaap',
#  'Bernice Schutte',
#  'Nora Hoppe',
#  'Maria Helena Matos',
#  'John Luebtow',
#  'John Lewis',
#  'Diana Hobson',
#  'Roberto Moretti',
#  'Stephen Brathwaite',
#  'Cork Marcheschi',
#  'Emmanuel Cooper',
#  'Marian Karel',
#  'Jack Benaroya',
#  'de Jong',
#  'Martin Blank',
#  'Dan Klein',
#  'Sheffield Phelps',
#  'Gerrit Benner',
#  'Archibald Dumbar',
#  'Per Sundberg',
#  'Paul Hoff',
#  'Bibi Smit',
#  'Justin Martin',
#  'John Gill',
#  'Edith Neff',
#  'Maarten Bon',
#  'Fred Kahl',
#  'Tina Bell',
#  'Bob Rodgers',
#  'H. Spoor',
#  'Peter Behrens',
#  'Geoffrey Beard',
#  'Wim Beeren',
#  'David Vaughan',
#  'Jeroen Voskuyl',
#  'Dan Dailey',
#  'Reidun Angell',
#  'Makoto Ito',
#  'Miriam Roth',
#  'Richard Meitner',
#  'Albert Lewis',
#  'Henry Geldzahler',
#  'Frits Gramberg',
#  'Raymond Peynet',
#  'David Hamilton',
#  'Jack Lenor Larsen',
#  'Pino Signoretto',
#  'Thomas Dimitroff',
#  'E. Van Damme',
#  'Philip Johnson',
#  'Louis Comfort Tiffany',
#  'Daniel Bergsma',
#  'Robert E. Day',
#  'Mary Lund Davis',
#  'David Dowler',
#  'Jean-Luc Olivié',
#  "Tim O'Neill",
#  'Lois Graham',
#  'Charles Bray',
#  'Ada Isensee',
#  'Nancy Walker',
#  'Elka Schrijver',
#  'Galina Popova',
#  'Herbert van Rheeden',
#  'David Wharton',
#  'Daniel Frederic',
#  'Mark Peiser',
#  'Erika Billeter',
#  'Ger Lataster',
#  'Patrick Martin',
#  'Annet Stunnenberg',
#  'James Tanner',
#  'Sergio Leone',
#  'Walter Lieberman',
#  'Heather Gray',
#  'Laurence Whistler',
#  'Sonja Blomdahl',
#  'Fred Tschida',
#  'John Spiers',
#  'Mary Ann Blakeney',
#  'John Anderson',
#  'Howard Ben Tré',
#  'Van Santen',
#  'Edward Lucie-Smith',
#  'Jacob Lawrence',
#  'Charles Parriott',
#  'Marijke de Goey',
#  'Johannes Schreiter',
#  'Juan Goytisolo',
#  'Clara Scremini',
#  'Harvey Littleton',
#  'Paul Brandt',
#  'Blanche Stuart Scott',
#  'Helmut Ricke',
#  'Peer Eriksson',
#  'Frans Berntsen',
#  'Pavel Hlava',
#  'Paul Woods',
#  'Ada Stroeve',
#  'Rob Levin',
#  'Linda MacNeil',
#  'Danny Perkins',
#  'Josephine van Gasteren',
#  'Natascha Emanuels',
#  'Bernard Brown',
#  'Albert S. Kerry',
#  'Dieter Schneider',
#  'Molly Stone',
#  'Jan Wolkers',
#  'Emma Brunt',
#  'Rolf Sinnemark',
#  'Thomas Bastide',
#  'G. Goossens',
#  'Timo Sarpaneva',
#  'Helly Oestreicher',
#  'Colette Probst',
#  'Gibson Byrd',
#  'Ans Wortel',
#  'Frans van Nieuwenborg',
#  'Cees van Olst',
#  'Marvin Lipofsky',
#  'Oiva Toikka',
#  'John Benson',
#  'Nicholas Hunter',
#  'Pierre Janssen',
#  'Jacques Blin',
#  'John Desmond',
#  'Bertus Hylkema',
#  'Margaret Mohr',
#  'Pat Clark',
#  'Channa Bankier',
#  'Katherine Bernstein',
#  'Martin Hunt',
#  'Charles Back',
#  'William Bernstein',
#  'Russell Lynes',
#  'John Bernhardt',
#  'Giovanni Battista',
#  'Esther Jiskoot',
#  'Therman Statom',
#  'Paul Huf',
#  'Jacques Nannan',
#  'Max Beckmann',
#  'Michael Bray',
#  'John Seitz',
#  'Paul Smith',
#  'Laura Russo',
#  'Lucie Rie',
#  'Helene Briels',
#  'Jan van Goethem',
#  'Gerda Rubinstein',
#  'Milan Handl',
#  'Gerrit van Iersel',
#  'Robert Koch',
#  'Linda Sullivan',
#  'Helen Frances Gregor',
#  'Susie Krasnican',
#  'John McKay',
#  'Johan Dijkstra',
#  'Jay Musler',
#  'Marion de Groot',
#  'David Pye',
#  'Marni Bakst',
#  'Benjamin Moore',
#  'Faith Ringgold',
#  'Antoine de Vinck',
#  'Manfred Maier',
#  'Sybren Valkema',
#  'Michael Taylor',
#  'Jean Fouquet',
#  'Elizabeth Sandvig',
#  'Henk Uterwijk',
#  'Pauline Wiertz',
#  'Juris Vics',
#  'Nancy Wolf',
#  'Bart de Vogel',
#  'Edward Hald',
#  'Mike Rowland',
#  'David Wolff',
#  'John Pine',
#  'Josef Albers',
#  'Finn Lynggaard',
#  'Michael Boylen',
#  'Piet Wiegman',
#  'Alexandre Noll',
#  'Jacques Mouclier',
#  'Maria van Kesteren',
#  'Arie van Loopik',
#  'Larry Bell',
#  'Alan Bluechel',
#  'Robert William',
#  'Ursula Andress',
#  'Janet Smith',
#  'Bruno Ninaber van Eyben',
#  'Harry Bertoia',
#  'Vincent van Gogh',
#  'Paul Revere',
#  'Annaliese Ohm',
#  'André Gide',
#  'Elizabeth Taylor',
#  'Wim Alings',
#  'Bertil Vallien',
#  'Mel Simpson',
#  'John Forster',
#  'Mary Lynn',
#  'Linda Fraser',
#  'Claus Joseph Riedel',
#  'Michael Cohn',
#  'Dick Broos',
#  'Kate Elliott',
#  'Mart Stam',
#  'Ann Hamilton',
#  'Ludwig Schaffrath',
#  'George Elliot',
#  'Michael Pavlik',
#  'Chris Peters',
#  'Herman Hermsen',
#  'Russell Johnson',
#  'Willem van Kuilenburg',
#  'Margie Jervis',
#  'Bert van Loo',
#  'Robert Loeffler',
#  'Jacques Lagrange',
#  'Herman Uhlhorn',
#  'Karla Trinkley',
#  'Gene Koss',
#  'Dick Nije',
#  'John Hatch',
#  'Robert Held',
#  'Ginny Ruffner',
#  'Mensje van Keulen',
#  'Rosemarie Lierke',
#  'Ingeborg Lundin',
#  'Monica Guggisberg',
#  'Olivier Leloup',
#  'Bennett Bean',
#  'Herman Scholten',
#  'Frederick Ayer',
#  'Matthew Black',
#  'Robert Fritz',
#  'Nikki Cass',
#  'Theo Valk',
#  'Hetty Huisman',
#  'Pierre Daems',
#  'Vincent van Ginneke',
#  'Keiko Ito',
#  'Carol Hall',
#  'Susanne K. Frantz',
#  'H. Simon',
#  'Tom Carpenter',
#  'Tirza Verrips',
#  'Nancy Graves',
#  'Irene Vonck',
#  'Kevin Lockau',
#  'Karel Appel',
#  'Thomas Rap',
#  'Karel Reiner',
#  'Peter Sellers',
#  'Norbert van den Broek',
#  'Mary Van Cline',
#  'Denise Gatard',
#  'Esther Cohen',
#  'Jan Dries',
#  'Luuc Ottens',
#  'Charles Nolan',
#  'Wout van Andel',
#  'David Reekie',
#  'Gerald Rose',
#  'Jesse Besser',
#  'Winnie Teschmacher',
#  'Claus Josef Riedel',
#  'Kimiko Kogure',
#  'Jan van der Vaart',
#  'Kenneth Clark',
#  'John Hauberg',
#  'Shirley Polykoff',
#  'Erik Oldenhof',
#  'Atsushi Takeda',
#  'John Bingham',
#  'Shelley Jurs',
#  'Dean Meeker',
#  'Gary Nash',
#  'Wil Bertheux',
#  'William Wiley',
#  'Neil Wilkin',
#  'Abraham Rattner',
#  'Miro Bernat',
#  'Anna Carlgren',
#  'Elizabeth Swinburne',
#  'Petr Novotny',
#  'Nancy Rudolph',
#  'Albert Neuhuys',
#  'Jeannelotte Hertzberger',
#  'Stig Lindberg',
#  'Stuart Davis',
#  'Viola Frey',
#  'Willem de Kooning',
#  'Don Johns',
#  'Aristide Maillol',
#  'R. Wagner',
#  'Paul Reilly',
#  'Bart Tromp',
#  'Annemie Groenen',
#  'Mieke Pontier',
#  'Jean Lowe',
#  'Karl Philipp',
#  'Abram Lerner',
#  'Judith Schaechter',
#  'Hans Appenzeller',
#  'Ray King',
#  'David Levi',
#  'Frederick Carder',
#  'Otto Schedl',
#  'Jacob Kramer',
#  'Carrie Lee',
#  'Jules Aarons',
#  'Tom Alberg',
#  'Joanna Walker',
#  'B. Dubbe',
#  'Jan-Willem van Zijst',
#  'Michael Scheiner',
#  'Janet Christensen',
#  'Joseph Cavallaro',
#  'Jaroslav Benda',
#  'Barbara Kroon',
#  'Piero Piccioni',
#  'Jos Lerinckx',
#  'Hugo Wolf',
#  'Horst Tappert',
#  'Bert Haanstra',
#  'Steve Myers',
#  'Ad Louwinger',
#  'Pat Wallace',
#  'Lodewijk de Boer',
#  'Kea Verwey',
#  'Hank Adams',
#  'Mary Robinson',
#  'Michael Maples',
#  'Kurt Wallstab',
#  'Ray Emery',
#  'Carol Damian',
#  'James Shipley',
#  'Philip Baldwin',
#  'Erik Plooyer',
#  'James Bond',
#  'Thomas C. MacAvoy',
#  'Ruth King',
#  'Gillian Lowndes',
#  'Carl Powell',
#  'Graham Hughes',
#  'Brian Clarke',
#  'Jan Hladik',
#  'Ludwig Thoma',
#  'John Lawrie',
#  'Takako Suzuki',
#  'Ann Lawrence',
#  'Eli Wallach',
#  'Lou Lynn',
#  'Mark Gibeau',
#  'Norman Schulman',
#  'Wim Crouwel',
#  'Glenn Ford',
#  'Gerrit Rietveld',
#  'Jochem Poensgen',
#  'Jeff Smith',
#  'Kees Hos',
#  'Little Rock',
#  'Ludwig Gosewitz',
#  'Peter Bakker',
#  'Jasperina de Jong',
#  'Albert Diato',
#  'Alec Guinness',
#  'Margaret Pennington',
#  'Carlyn Steiner',
#  'Pieter Engels',
#  'Susan Anton',
#  'Maureen Michelson',
#  'Lies Cosijn',
#  'Helen Smith',
#  'Richard Jolley',
#  'Amy Roberts',
#  'Art Jones',
#  'Nicholas Stephens',
#  'Paul Jones',
#  'Ronald Markman',
#  'Robert Strini',
#  'Cappy Thompson',
#  'Bob Reid',
#  'Thomas Farbanish',
#  'Mary Shirley',
#  'Mario Prassinos',
#  'Nicholas Africano',
#  'Waldemar Haberey',
#  'Italo Scanga',
#  'Karen Klim',
#  'Mieke Blits',
#  'Kenneth Callahan',
#  'Peter Vos',
#  'Brian Hughes',
#  'Jan Oosterman',
#  'Kevin Gray',
#  'Judith Cohen',
#  'Nico Witteman',
#  'David Wright',
#  'Ernst Ludwig',
#  'John Swartz',
#  'Dennis Oppenheim',
#  'Richard Whiteley',
#  'Kiki Smith',
#  'Maurice Gensoli',
#  'Wayne Higby',
#  'Joop van den Broek',
#  'Catherine Thompson',
#  'Paul Marioni',
#  'Lynda Benglis',
#  'James Harmon',
#  'Chris Lanooy',
#  'George Peabody',
#  'Rob Herwig',
#  'Milan Vobruba',
#  'Jan van Zanen',
#  'Jim Wilson',
#  'Raoul Goldoni',
#  'Jan Sadeler',
#  'George Taylor',
#  'Yvonne Vincke',
#  'Victor Onstein',
#  'Robert M',
#  'James Renwick',
#  'Eva Vlasakova',
#  'Robert O. Smith',
#  'Mutsuo Inoue',
#  'Aad Hoetjes',
#  'Mieke Groot',
#  'Raymond Burr',
#  'Jane Bruce',
#  'Joost Bicker Caarten',
#  'Don Hansen',
#  'Paul B. Brown',
#  'Tije Domburg',
#  'Daniel Baty',
#  'Edmond Bellefroid',
#  'Udo Edelmann',
#  'Hans Harald Rath',
#  'Adolf Loos',
#  'Dorothy Anderson',
#  'Claude Morin',
#  'W. de Bruyn',
#  'Hans Verhagen',
#  'Tom Boone',
#  'Flip Schrameijer',
#  'Melinda Miller',
#  'Lucienne Bloch',
#  'Madeleine Dupont',
#  'Sien van Meurs',
#  'Frank Cassenti',
#  'Dante Marioni',
#  'Bruce Chao',
#  'Sam Herman',
#  'Jennifer Owens',
#  'Jacques Gans',
#  'Henny Visch',
#  'Giselle Courtney',
#  'Richard Craig',
#  'Lambertus Zijl',
#  'Rod Steiger',
#  'Margaretha Verwey',
#  'John Reed',
#  'Hans Gottfried von Stockhausen',
#  'Martin Woods',
#  'Richard Marquis',
#  'Mien Ruys',
#  'Robert Stone',
#  'Theo Mackaay',
#  'David MacGregor',
#  'Pierre Caille',
#  'Clifford Rainey',
#  'Michel Rayne',
#  'Marshall Hatch',
#  'Arlon Bayliss',
#  'Thomas Oelzner',
#  'Ina Broerse',
#  'Hans de Ruiter',
#  'Henry Halem',
#  'Harrie Geelen']

# %%
from tqdm.auto import tqdm

qid_per_name = {
    name: disambiguate(name)
    for name in tqdm(wiki_people_fullnames)
}
# Out:
#   0%|          | 0/873 [00:00<?, ?it/s]

# %%
qid_per_name

# %%
import json

json.dump(qid_per_name, open('wikidata_id_per_name_latest.json','w'),indent=6)

# %%
df_graph_with_qids = df_graph[df_graph['person1'].isin(qid_per_name) & df_graph['person2'].isin(qid_per_name)]

# %%
df_graph_with_qids

# %%
df_graph_with_qids['wikidata_id1'] = df_graph_with_qids['person1'].map(lambda x: qid_per_name[x][0])
df_graph_with_qids['wikidata_description1'] = df_graph_with_qids['person1'].map(lambda x: qid_per_name[x][1])

df_graph_with_qids['wikidata_id2'] = df_graph_with_qids['person2'].map(lambda x: qid_per_name[x][0])
df_graph_with_qids['wikidata_description2'] = df_graph_with_qids['person2'].map(lambda x: qid_per_name[x][1])

df_graph_with_qids.drop(['candidates1','candidates2'],axis=1,inplace=True)

# %%
df_graph_with_qids

# %%
df_graph_with_qids.to_csv('df_graph_with_wikidata.tsv',sep='\t',index=False)

# %%
# todo fix some errors: eg. Wim Crouwel

# %%
### Old code begins here


%
# https://graphvite.io/docs/latest/pretrained_model.html

# import sys
# !{sys.executable} -m pip install easydict

import pickle

with open("/ivi/ilps/personal/vprovat/rotate_wikidata5m.pkl", "rb") as fin:
    model = pickle.load(fin)
entity2id = model.graph.entity2id
relation2id = model.graph.relation2id
entity_embeddings = model.solver.entity_embeddings
relation_embeddings = model.solver.relation_embeddings

%
import numpy as np
from scipy.spatial.distance import cosine

# Example embeddings (vectors)
embedding1 = np.array([0.1, 0.2, 0.5, 0.8])
embedding2 = np.array([0.3, 0.4, 0.7, 0.9])

# Calculate Cosine Similarity
cosine_similarity = 1 - cosine(embedding1, embedding2)
print(f"Cosine Similarity: {cosine_similarity}")


%
def similarity(q1, q2):
    if q1 not in entity2id:
        print('No embedding for ',q1)
        return 0
    if q2 not in entity2id:
        print('No embedding for ',q2)
        return 0
    
    id1, id2 = entity2id[q1], entity2id[q2]
    embedding1, embedding2 = entity_embeddings[id1],entity_embeddings[id2]
    
    return 1 - cosine(embedding1, embedding2)

similarity('Q15488059','Q2618110')

# %%
from sentence_transformers import SentenceTransformer, util

# Example sentences
sentence1 = "This is sentence one."
sentence2 = "This is sentence two."

# Load SBERT model
model = SentenceTransformer('sentence-transformers/paraphrase-xlm-r-multilingual-v1')

# Encode sentences into embeddings
embeddings = model.encode([sentence1, sentence2], convert_to_tensor=True)

# Calculate cosine similarity between the embeddings
cosine_scores = util.pytorch_cos_sim(embeddings[0], embeddings[1])
similarity_score = cosine_scores.item()

print(f"Cosine Similarity: {similarity_score}")

# %%
def text_similarity(q1, q2):
    s1 = get_wikidata_description(q1)
    s2 = get_wikidata_description(q2)
    embeddings = model.encode([s1, s2], convert_to_tensor=True)

    cosine_scores = util.pytorch_cos_sim(embeddings[0], embeddings[1])
#     print(cosine_scores)
    similarity_score = cosine_scores.item()
    return similarity_score

for link in wikidata_candidates_per_name['Sybren Valkema']:
    qid = link.split('/')[-1]
    print(link)
    print(text_similarity(qid,'Q29422094'))
