# %%
import pandas as pd
df_entities = pd.read_csv('all_lettters_with_entities_final.tsv',sep='\t')

# %%
df_entities.head()
# Out:
#                                        part_of.title  \
# 0  Correspondence, editorial office 'Goed Wonen' ...
# 1  Correspondence, editorial office 'Goed Wonen' ...
# 2  Correspondence, editorial office 'Goed Wonen' ...
# 3  Correspondence, editorial office 'Goed Wonen' ...
# 4  Correspondence, editorial office 'Goed Wonen' ...
#
#                    images.reference   filename  is_missing  \
# 0  ..\images\jpg\757\0001246757.jpg  1246757.0       False
# 1  ..\images\jpg\763\0001246763.jpg  1246763.0       False
# 2  ..\images\jpg\765\0001246765.jpg  1246765.0       False
# 3  ..\images\jpg\767\0001246767.jpg  1246767.0       False
# 4  ..\images\jpg\769\0001246769.jpg  1246769.0       False
#
#                                        path_to_image page_type  \
# 0  /ivi/ilps/projects/ArtDATIS/valkema/MMRKD07_00...     typed
# 1  /ivi/ilps/projects/ArtDATIS/valkema/MMRKD07_00...     typed
# 2  /ivi/ilps/projects/ArtDATIS/valkema/MMRKD07_00...     typed
# ...

# %%
df_entities[df_entities['filename']==1288226]
# Out:
#                                           part_of.title  \
# 4496  Correspondence with Maurine Littleton, Maurine...
#
#                       images.reference   filename  is_missing  \
# 4496  ..\images\jpg\226\0001288226.jpg  1288226.0       False
#
#                                           path_to_image           page_type  \
# 4496  /ivi/ilps/projects/ArtDATIS/valkema/MMRKD07_00...  likely handwritten
#
#                                            path_to_text  \
# 4496  /ivi/ilps/personal/vprovat/Valkema_HTR_results...
#
#                                path_to_handwritten_info  \
# 4496  /ivi/ilps/personal/vprovat/backup_ocr/new_resu...
#
#                                                  people  \
# 4496  {'Sybren', 'Urine Littleton', 'Mauri e', 'Sybr...
#
#                                        handwritten_info  \
# 4496  Page number: 0\nOrientation in degrees: 0\nRot...
#
#                                            people_split
# ...

# %%
df_entities.nunique()
# Out:
# part_of.title                 52
# images.reference            5833
# filename                    5833
# is_missing                     1
# path_to_image               5833
# page_type                      2
# path_to_text                5833
# path_to_handwritten_info    3688
# people                      3345
# handwritten_info            1574
# people_split                3209
# dtype: int64

# %%
import pandas as pd
df_graph = pd.read_csv('df_graph_with_wikidata.tsv',sep='\t')

# %%
df_graph
# Out:
#                person1           person2  \
# 0       Sybren Valkema       Wim Crouwel
# 1        Bert Haanstra    Sybren Valkema
# 2           Jane Bruce    Sybren Valkema
# 3       Frits Gramberg    Sybren Valkema
# 4        Bert Haanstra       Wim Crouwel
# ...                ...               ...
# 37554    George Elliot   Gerrit Rietveld
# 37555    George Elliot       Mieke Groot
# 37556  Barbara Vaessen     George Elliot
# 37557    George Elliot  Harvey Littleton
# 37558    George Elliot     Willem Heesen
#
#                                             document_ids wikidata_id1  \
# 0      ['0001246763-0001246764-0001246765-0001246766-...     Q2618110
# 1      ['0001246763-0001246764-0001246765-0001246766-...      Q827371
# 2      ['0001246763-0001246764-0001246765-0001246766-...    Q16031419
# 3      ['0001246763-0001246764-0001246765-0001246766-...    Q42429178
# 4      ['0001246763-0001246764-0001246765-0001246766-...      Q827371
# ...

# %%
df_for_evaluation=pd.read_csv('sample_for_manual_evaluation_FINAL.tsv',sep='\t')

# %%
df_for_evaluation
# Out:
#                   person1             person2  filename  \
# 0          Sybren Valkema     Herman Scholten   1269442
# 1             Irene Vonck    Harvey Littleton   1266713
# 2          Sybren Valkema   Susanne K. Frantz   1290802
# 3        Harvey Littleton        Albert Lewis   1311201
# 4              Sam Herman          Joel Myers   1311209
# 5           Kyohei Fujita       Roman Bartkiw   1311201
# 6           Willem Heesen         Jan Wolkers   1308126
# 7          Frits Gramberg           Mart Stam   1258393
# 8          Sybren Valkema     Gerrit Rietveld   1268554
# 9          Sien van Meurs       Floris Meydam   1311171
# 10          Carolyn Adams        Albert Lewis   1311217
# 11           Durk Valkema         Mieke Groot   1311185
# 12       Joost van Santen     Miroslav Vondra   1311203
# 13            Mieke Groot     Richard Meitner   1311185
# 14  Norbert van den Broek  Joop van den Broek   1311203
# 15         Sybren Valkema         Gibson Byrd   1268564
# ...

# %%
wikidata = set(df_for_evaluation['wikidata_id1'].tolist()+df_for_evaluation['wikidata_id2'].tolist())

# %%
len(wikidata)
# Out:
# 37
