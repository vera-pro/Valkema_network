# %%
def extract_filename(path):
    return path.split('/')[-1].split('.')[0].split('_')[0]

# %%
import os
def getListOfFiles(dirName):
    # create a list of file and sub directories 
    # names in the given directory 
    listOfFile = os.listdir(dirName)
    allFiles = list()
    # Iterate over all the entries
    for entry in listOfFile:
        # Create full path
        fullPath = os.path.join(dirName, entry)
        # If entry is a directory then get the list of files in this directory 
        if os.path.isdir(fullPath):
            allFiles = allFiles + getListOfFiles(fullPath)
        else:
            allFiles.append(fullPath)
                
    return allFiles

# %%
import pandas as pd

# %%
df_files = pd.read_csv('archive_files_with_paths_and_descriptions.tsv',sep='\t')

# %%
def recover_filename(f_raw):
    f = str(f_raw)
    while len(f) < len('0001246757'):
        f = '0'+f
    return f

# %%
df_files['filename'] = df_files.apply(lambda row: recover_filename(row['filename']),
                                       axis=1)

# %%
df_files.head()
# Out:
#    Unnamed: 0                                      part_of.title  \
# 0           1  Correspondence, editorial office 'Goed Wonen' ...
# 1           2  Correspondence, editorial office 'Goed Wonen' ...
# 2           3  Correspondence, editorial office 'Goed Wonen' ...
# 3           4  Correspondence, editorial office 'Goed Wonen' ...
# 4           5  Correspondence, editorial office 'Goed Wonen' ...
#
#                    images.reference    filename  is_missing  \
# 0  ..\images\jpg\757\0001246757.jpg  0001246757       False
# 1  ..\images\jpg\758\0001246758.jpg  0001246758       False
# 2  ..\images\jpg\759\0001246759.jpg  0001246759       False
# 3  ..\images\jpg\760\0001246760.jpg  0001246760       False
# 4  ..\images\jpg\761\0001246761.jpg  0001246761       False
#
#                                        path_to_image
# 0  /ivi/ilps/projects/ArtDATIS/valkema/MMRKD07_00...
# 1  /ivi/ilps/projects/ArtDATIS/valkema/MMRKD07_00...
# 2  /ivi/ilps/projects/ArtDATIS/valkema/MMRKD07_00...
# 3  /ivi/ilps/projects/ArtDATIS/valkema/MMRKD07_00...
# 4  /ivi/ilps/projects/ArtDATIS/valkema/MMRKD07_00...

# %%
# todo: classify typed vs handwritten (or get info for those already classified)

# %%
path_typed_old = '/ivi/ilps/projects/ArtDATIS/artdatis/tagging/OCRed/typed/'
path_typed_new = '/ivi/ilps/personal/vprovat/ocr/newest_results/typed/'

# %%
typed_files = list(set(getListOfFiles(path_typed_old)+getListOfFiles(path_typed_new)))

# %%
texts_typed = [f for f in typed_files if f.endswith('text.txt')]

# %%
len(texts_typed)
# Out:
# 34196

# %%
# filenames_typed = set([f.split('/')[-1].split('.')[0] for f in texts_typed])

# %%
path_handwritten = '/ivi/ilps/personal/vprovat/backup_ocr/handwritten/'
path_no_text = '/ivi/ilps/personal/vprovat/backup_ocr/no_text/'
path_no_text_new = '/ivi/ilps/personal/vprovat/backup_ocr/new_results/non-typed/'

# %%
non_typed_file_paths = [f for f in list(set(getListOfFiles(path_handwritten)+getListOfFiles(path_no_text)+getListOfFiles(path_no_text_new)))
                        if f.endswith('path.txt')]

# %%
non_typed_file_osds = [f for f in list(set(getListOfFiles(path_handwritten)+getListOfFiles(path_no_text)+getListOfFiles(path_no_text_new)))
                        if f.endswith('osd.txt')]

# %%
dict_typed_text_paths = dict([(extract_filename(path), path) for path in texts_typed])
dict_non_typed_paths = dict([(extract_filename(path), path) for path in non_typed_file_paths])

# %%
# sanity check
set(dict_typed_text_paths.keys()).intersection(set(dict_non_typed_paths.keys()))
# Out:
# {'NL-HaRKD'}

# %%
# another sanity check: do we have them all?
len(set(dict_typed_text_paths.keys()))+len(set(dict_non_typed_paths.keys()))-len(df_files)
# Out:
# 0

# %% [markdown]
# Now, let's try to detect handwritten files among the non-typed ones (and label others as likely drawings):

# %%
drawing_files = set()
handwritten_files = set()
dict_handwritten_osd_paths = {}

# %%
from tqdm import tqdm

# %%
for path in tqdm(non_typed_file_osds):
    name = extract_filename(path)
    osd = open(path,'r').read()
    if not osd:
        drawing_files.add(name)
    else:
        handwritten_files.add(name)
        dict_handwritten_osd_paths[name] = path
# Out:
# 100%|██████████| 90881/90881 [07:24<00:00, 204.67it/s]

# %%
typed_files = set(dict_typed_text_paths.keys())

# %%
# Handling empty stuff to avoid errors
for f in df_files['filename'].tolist():
    if f not in dict_typed_text_paths:
        dict_typed_text_paths[f] = None
    if f not in dict_handwritten_osd_paths:
        dict_handwritten_osd_paths[f] = None

# %%
def get_page_class(f):
    if f in typed_files:
        return "typed"
    if f in handwritten_files:
        return "likely handwritten"
    if f in drawing_files:
        return "likely drawing"
    return None

# %%
df_files['page_type'] = df_files.apply(lambda row: get_page_class(row['filename']),
                                       axis=1)

# %%
df_files['path_to_text'] = df_files.apply(lambda row: dict_typed_text_paths[row['filename']],
                                       axis=1)

# %%
df_files['path_to_handwritten_info'] = df_files.apply(lambda row: dict_handwritten_osd_paths[row['filename']],
                                       axis=1)

# %%
df_files.head()
# Out:
#    Unnamed: 0                                      part_of.title  \
# 0           1  Correspondence, editorial office 'Goed Wonen' ...
# 1           2  Correspondence, editorial office 'Goed Wonen' ...
# 2           3  Correspondence, editorial office 'Goed Wonen' ...
# 3           4  Correspondence, editorial office 'Goed Wonen' ...
# 4           5  Correspondence, editorial office 'Goed Wonen' ...
#
#                    images.reference    filename  is_missing  \
# 0  ..\images\jpg\757\0001246757.jpg  0001246757       False
# 1  ..\images\jpg\758\0001246758.jpg  0001246758       False
# 2  ..\images\jpg\759\0001246759.jpg  0001246759       False
# 3  ..\images\jpg\760\0001246760.jpg  0001246760       False
# 4  ..\images\jpg\761\0001246761.jpg  0001246761       False
#
#                                        path_to_image           page_type  \
# 0  /ivi/ilps/projects/ArtDATIS/valkema/MMRKD07_00...               typed
# 1  /ivi/ilps/projects/ArtDATIS/valkema/MMRKD07_00...  likely handwritten
# 2  /ivi/ilps/projects/ArtDATIS/valkema/MMRKD07_00...  likely handwritten
# 3  /ivi/ilps/projects/ArtDATIS/valkema/MMRKD07_00...  likely handwritten
# 4  /ivi/ilps/projects/ArtDATIS/valkema/MMRKD07_00...  likely handwritten
#
#                                         path_to_text  \
# 0  /ivi/ilps/projects/ArtDATIS/artdatis/tagging/O...
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#                             path_to_handwritten_info
# 0                                               None
# 1  /ivi/ilps/personal/vprovat/backup_ocr/handwrit...
# 2  /ivi/ilps/personal/vprovat/backup_ocr/new_resu...
# 3  /ivi/ilps/personal/vprovat/backup_ocr/new_resu...
# 4  /ivi/ilps/personal/vprovat/backup_ocr/new_resu...

# %%
remaining_paths_to_classify = df_files[df_files['page_type'].isna()]['path_to_image'].tolist()

# %%
len(remaining_paths_to_classify)
# Out:
# 6505

# %%
# Classify the missing files with tesseract

# %%
import pytesseract
import json

try:
    from PIL import Image
except ImportError:
    import Image

RES_PATH = '/ivi/ilps/personal/vprovat/OCR_for_missing_folders'
    
    
def process_document(path):
    name = extract_filename(path)
    try:
        img = Image.open(path)
    except: # path not found
        return
    
    try:
        osd_dict = pytesseract.image_to_osd(img, output_type='dict')
    except: # Too few characters for osd -> most likely blank or drawing, could also be handwritten
        with open(f"{RES_PATH}/likely_drawing/{name}_path.txt","w") as f:
            f.write(path)
        return
        
    
    if osd_dict['script'] == 'Latin': # Is a typed document
        with open(f"{RES_PATH}/typed/{name}_path.txt","w") as f:
            f.write(path)
            
        text = pytesseract.image_to_string(img)
        with open(f"{RES_PATH}/typed/{name}_text.txt","w") as f:
            f.write(text)
    else: # We think it's handwritten, saving osd just in case
        with open(f"{RES_PATH}/likely_handwritten/{name}_path.txt","w") as f:
            f.write(path)
        with open(f"{RES_PATH}/likely_handwritten/{name}_osd.txt","w") as f:
            f.write(json.dumps(osd_dict))

# %%
# import parmap

# %%
# parmap.map(process_document, remaining_paths_to_classify[-1000:], pm_processes=8, pm_pbar=True)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1000.0), HTML(value='')))

# %%
new_typed_dict = dict([(extract_filename(f), f) for f in getListOfFiles('/ivi/ilps/personal/vprovat/OCR_for_missing_folders/typed') if f.endswith('text.txt')])
new_handwritten_dict = dict([(extract_filename(f), f) for f in getListOfFiles('/ivi/ilps/personal/vprovat/OCR_for_missing_folders/likely_handwritten') if f.endswith('osd.txt')])
new_drawing_dict = dict([(extract_filename(f), f) for f in getListOfFiles('/ivi/ilps/personal/vprovat/OCR_for_missing_folders/likely_drawing')])

# %%
def path_already_processed(path):
    f = extract_filename(path)
    return (f in new_typed_dict) or (f in new_handwritten_dict) or (f in new_drawing_dict)

# %%
# in case we need to update
still_remaining_paths_to_classify = [path for path in remaining_paths_to_classify if not path_already_processed(path)
                                    ]

# %%
len(still_remaining_paths_to_classify)
# Out:
# 2

# %%
import parmap
parmap.map(process_document, still_remaining_paths_to_classify, pm_processes=2, pm_pbar=True)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# [None, None]

# %%
import pickle
pickle.dump(still_remaining_paths_to_classify, open('paths_to_classify.p','wb'))

# %%
def update_classification(row):
    if row['page_type']:
        return row['page_type']
    f = row['filename']
    if f in new_typed_dict:
        return "typed"
    if f in new_handwritten_dict:
        return "likely handwritten"
    if f in new_drawing_dict:
        return "likely drawing"
    
    return None

# %%
def update_osd(row):
    if row['path_to_handwritten_info']:
        return row['path_to_handwritten_info']
    
    f = row['filename']
    if f in new_handwritten_dict:
        return new_handwritten_dict[f]
    return None

# %%
def update_text(row):
    if row['path_to_text']:
        return row['path_to_text']
    
    f = row['filename']
    if f in new_typed_dict:
        return new_typed_dict[f]
    return None

# %%
df_files['page_type'] = df_files.apply(lambda row: update_classification(row),
                                       axis=1)

df_files['path_to_handwritten_info'] = df_files.apply(lambda row: update_osd(row),
                                       axis=1)

df_files['path_to_text'] = df_files.apply(lambda row: update_text(row),
                                       axis=1)

# %%
import csv

# %%
df_files.to_csv('archive_files_with_paths_descriptions_and_page_classifications.tsv',sep='\t', quoting=csv.QUOTE_NONNUMERIC)

# %%
df_files
# Out:
#         Unnamed: 0                                      part_of.title  \
# 0                1  Correspondence, editorial office 'Goed Wonen' ...
# 1                2  Correspondence, editorial office 'Goed Wonen' ...
# 2                3  Correspondence, editorial office 'Goed Wonen' ...
# 3                4  Correspondence, editorial office 'Goed Wonen' ...
# 4                5  Correspondence, editorial office 'Goed Wonen' ...
# ...            ...                                                ...
# 102156      103029                                          1943-1944
# 102157      103030                                          1943-1944
# 102158      103031                                          1943-1944
# 102159      103032                                          1943-1944
# 102160      103033                                          1943-1944
#
#                         images.reference    filename  is_missing  \
# 0       ..\images\jpg\757\0001246757.jpg  0001246757       False
# 1       ..\images\jpg\758\0001246758.jpg  0001246758       False
# 2       ..\images\jpg\759\0001246759.jpg  0001246759       False
# 3       ..\images\jpg\760\0001246760.jpg  0001246760       False
# 4       ..\images\jpg\761\0001246761.jpg  0001246761       False
# ...                                  ...         ...         ...
# 102156  ..\images\jpg\329\0001447329.jpg  0001447329       False
# 102157  ..\images\jpg\330\0001447330.jpg  0001447330       False
# 102158  ..\images\jpg\331\0001447331.jpg  0001447331       False
# 102159  ..\images\jpg\332\0001447332.jpg  0001447332       False
# 102160  ..\images\jpg\333\0001447333.jpg  0001447333       False
#
#                                             path_to_image           page_type  \
# 0       /ivi/ilps/projects/ArtDATIS/valkema/MMRKD07_00...               typed
# 1       /ivi/ilps/projects/ArtDATIS/valkema/MMRKD07_00...  likely handwritten
# 2       /ivi/ilps/projects/ArtDATIS/valkema/MMRKD07_00...  likely handwritten
# 3       /ivi/ilps/projects/ArtDATIS/valkema/MMRKD07_00...  likely handwritten
# 4       /ivi/ilps/projects/ArtDATIS/valkema/MMRKD07_00...  likely handwritten
# ...                                                   ...                 ...
# 102156  /ivi/ilps/personal/vprovat/missing_folders_Art...      likely drawing
# 102157  /ivi/ilps/personal/vprovat/missing_folders_Art...               typed
# 102158  /ivi/ilps/personal/vprovat/missing_folders_Art...      likely drawing
# 102159  /ivi/ilps/personal/vprovat/missing_folders_Art...      likely drawing
# 102160  /ivi/ilps/personal/vprovat/missing_folders_Art...      likely drawing
#
#                                              path_to_text  \
# 0       /ivi/ilps/projects/ArtDATIS/artdatis/tagging/O...
# 1                                                    None
# 2                                                    None
# 3                                                    None
# 4                                                    None
# ...                                                   ...
# 102156                                               None
# 102157  /ivi/ilps/personal/vprovat/OCR_for_missing_fol...
# 102158                                               None
# 102159                                               None
# 102160                                               None
#
#                                  path_to_handwritten_info
# 0                                                    None
# 1       /ivi/ilps/personal/vprovat/backup_ocr/handwrit...
# 2       /ivi/ilps/personal/vprovat/backup_ocr/new_resu...
# 3       /ivi/ilps/personal/vprovat/backup_ocr/new_resu...
# 4       /ivi/ilps/personal/vprovat/backup_ocr/new_resu...
# ...                                                   ...
# 102156                                               None
# 102157                                               None
# 102158                                               None
# 102159                                               None
# 102160                                               None
#
# [102161 rows x 9 columns]

# %%
# prepare for network analysis on letters: find letters, extract names (to, from)
#

# %%
descriptions = sorted(list(set(df_files['part_of.title'].tolist())))

# %%
descriptions
# Out:
# ["'10 jaar Vrij Glas op de Rietveld Academie', Centrum De Vaart, Hilversum, 23 June - 22 July 1979",
#  "'Encyclopédie, ou Dictionnaire Universel Raisonné des Connoissance Humaines'",
#  "'Vrij Glas', Hengelose Kunstzaal, 18 February - 18 May 1978",
#  "10th Jubilee 'Werkgroep Glas', 14 September 1979",
#  '1934',
#  '1935, or undated',
#  '1936',
#  '1936 (Part 1)',
#  '1936 (Part 2)',
#  '1937',
#  '1937 (Part 3)',
#  '1938',
#  '1939',
#  '1939, part 2',
#  '1940',
#  '1941',
#  '1942',
#  '1943',
#  '1943-1944',
#  '1943-1947',
#  '1944',
#  '1945',
#  '1946',
#  '1947',
#  '1948',
#  '1949',
#  '1950',
#  '1951',
#  '1952',
#  '1953',
#  '1954',
#  '1955',
#  '1956',
#  '1957',
#  '1958',
#  '1959',
#  '1960',
#  '1961',
#  '1962',
#  '1963',
#  '1963-1964',
#  '1963-1993',
#  '1964',
#  '1964-1965',
#  '1965',
#  '1965-1966',
#  '1966',
#  '1966-1967',
#  '1967',
#  '1968',
#  '1970',
#  '1971',
#  '1972',
#  '1973',
#  '1973-1975, 1992-1993',
#  '1974',
#  '1975',
#  '1976',
#  '1977',
#  '1978',
#  '1979',
#  '1980',
#  '1980-1981',
#  '1981',
#  '1982',
#  '1983',
#  '1983-1984',
#  '1984',
#  '1985',
#  '1985-1986',
#  '1986',
#  '1986-1987',
#  '1987',
#  '1987-1988',
#  '1987-1989',
#  '1988',
#  '1988-1989',
#  '1989',
#  '1989-1990',
#  '1989-1991',
#  '1990',
#  '1990-1991',
#  '1991',
#  '1991-1993',
#  '1992',
#  '1993',
#  '237 Sample van textiel in passe-partout Textile sample in passe-partout',
#  '2nd International Glass Symposium, Glasmuseum Frauenau, 15-19 May 1985',
#  '3rd International Glass Symposium, Frauenau, 11-15 May 1988',
#  '4th International Glass Symposium, Frauenau, organised by Glasmuseum Frauenau, 8-12 May 1991',
#  '60th Jubilee Süssmuth Manufaktur',
#  '9 drawings, spindles for cutting, engraving and polishing, in an envelope',
#  "A.I.H.V. Association Internationale pour l'Histoire du Verre', concerning the membership",
#  'Academic subject Technical Drawing, including assignments calculating volumes',
#  "Acquisition of art works by the commission 'Rijksadviescommissie Gebonden Kunsten'",
#  "Additional texts about glassmaking techniques, school subjects at the 'Glasschool Leerdam'",
#  "Address list with the participants 'Hommage voor Bernardine de Neeve' given to Anna Carlgren by Klaas Laansma",
#  'Address lists with notes used for mailings',
#  'Advertising photograph of the series Compact in a specially designed packaging',
#  'American Interfaith Institute',
#  'American universities and museums, publications',
#  'Andrews, Rosemary',
#  'Ann Waerff',
#  "Announcement sign 'Geschiedenis van het glas, geschiedenis van twee krachten' (History of glass, history of two forces) publicising the theatre play 'Sulifor en Polipos' by the pupils at the 'Glasschool Leerdam' directed by Sybren Valkema and performed for the 'IvKNO' and the 'Normaalschool'",
#  "Applicants from aspirant students 'Werkgroep Glas'",
#  "Architectural drawings with calculations and notes for the (re-) building of the glass studio at the house of Sybren Valkema in Blaricum, also known as 'het hutje in de bos'; contains large format drawings",
#  "Art Contemporain du Verre', Rouen",
#  'Art Glass Akademie, Wien, 27 June-11 July 1985',
#  'Art commission policy change',
#  "Article 'Vrij Glas: een opmerkelijke ontwikkeling in de glaskunst'(Vrij Glas: a remarkable development in glass art) on two pieces transparent plastic, not complete",
#  "Article 'Weven in Noordafrika' published in 'Kroniek der Witte Zusters' 1957",
#  'Articles about the history of glass in Czechoslovakia, in German',
#  "Articles, including 'Wegwijs in de plastic dolhof [sic]' in Libelle, and catalogues from 1958",
#  'Assignment about distinctive tools including a section about Pablo Picasso and Cubism',
#  'Assignment: Dressing in the 19th century',
#  "Atelier '70 Joop van Den Broek",
#  'Atkinson, David',
#  'Axonometry and other calculation formula',
#  "BBK '69, received documents",
#  "Beeldende Kunst in Zeeland'",
#  'Bingham, John',
#  'Black and white photographs of The Great Glass Symposium 1968 at the University of California, Berkeley and California College of Arts and Crafts',
#  "Black and white photographs of designs by Sybren Valkema executed at the 'Glasschool Leerdam'",
#  "Black and white photographs of the 'Werkgroep Glas' at the Gerrit Rietveld Academie",
#  "Black and white photographs of the 'Werkgroep Glas' at the Gerrit Rietveld Academie, including a master class by Leen van der Linden, master glassblower Glass Factory Leerdam",
#  'Black and white photographs of work by Sybren Valkema',
#  'Blue cover',
#  'Book about glass written by Mr. and Mrs. Grover (Cleveland, Ohio) featuring three pieces by Sybren Valkema',
#  "Booklet 'Het woud en de houthakker' (The forest and the lumberjack), signed G. v. Luit",
#  "Booklet 'Vormleer' (Form theory) signed Wim van Stek",
#  "Bound year volumes of 'De Zwerver, Maandblad der Natuurhistorische Club De Zwervers'",
#  'Boëthius, Elin and Peer Eriksson',
#  'Braggiotti Gallery, Amsterdam',
#  'Brandt, Åsa',
#  "Brochure 'Zij staan er achter, wij zijn er voor' by the Vereenigde Glasfabrieken",
#  'Bronze casting instructions',
#  'Brown cover',
#  "Bulletin 'De Smelt': staff magazine for de 'N.V. Vereenigde Glasfabrieken' with an article about the official opening of the 'Glasvormcentrum' in Leerdam by Prince Bernhard, 27 September 1968",
#  'COSA membership',
#  "COSA, KIO, 'Instituut voor IndustriÃ«le Vormgeving'",
#  'Calculating thermal mass, heat-loss and outside wall temperature',
#  'Catalogues with notes',
#  'Ceramic Age, including the article Mixing tons of glass by pushbutton, Toledo. The use of Egyptian paste in making Ceramic Jewelry',
#  'Ceramics',
#  "Chapter from the thesis 'Nederlands Glas 1890-1990' by Greetje Huisman",
#  'Chesham Fine Art and Valtra Enterprises, Singapore',
#  'Claude Horan and Suzie Pleyte, Honolulu, Hawaii (black and white photographs)',
#  'Claude Monod, Isabelle Monod',
#  'Claude Morin',
#  'Claude Morin, Florence Morin, Frederique Morin',
#  'Clippings about glass',
#  'Clippings from Swedish newspapers about glass',
#  "Coburger Glaspreis 1977 fÃ¼r moderne Glasgestaltung in Europa / Coburg glass prize 1977 for modern European studio glass / Prix de Coburg 1977 pour l'art du verre contemporain de l'Europe: Weltbewerbsausstellung 23. Juli bis 3l. Oktober 1977 in Kunstsammlungen der Veste Coburg",
#  'Colour study by Barbara Strauss (design Sybren Valkema?)',
#  'Colour study in yellow and blue',
#  'Colour study, square',
#  'Colours consult Fa. Keune & Co',
#  'Competition Pattern Design for Curtains, initiated by Herman Hart & Co N.V.',
#  "Competition for 'Jonge Glaskunstenaars' (Young Glass Artists)",
#  'Competitions and exhibitions with IvKNO students, organised in collaboration with corporations',
#  "Concept curriculum 'Werkgroep Glas'",
#  'Concept glass lexicon by Sybren Valkema',
#  'Concept glass lexicon by Sybren Valkema, with notes',
#  "Concept text 'Valkema als ontwerper' by Thimo te Duits",
#  "Conference 'Art at Steuben', London",
#  "Congress 'Renouveau du Verre', Rouen, 12-15 September 1984",
#  "Contemporary European Sculptures in Crystal and Glass', Generale de Banque, LiÃ¨ge, 13 April-17 June 1989",
#  'Copier, Andries Dirk',
#  "Copies of articles about the 'Glasschool Leerdam' published in the glass factory's staff magazine and in-house organ 'Onze Bedrijfsgemeenschap O.B.G.'",
#  'Copy of a reader on furnace building, written by Robert Held, Sheridan College School of Design, Mississauga, Ontario',
#  'Correspondence',
#  "Correspondence about an exhibition in Cologne and the magazine 'Scheppend Ambacht', correspondence with J.A. de Melker",
#  "Correspondence and notes referring to awards instituted by 'Vereniging Vrienden van Modern Glas'",
#  'Correspondence and received documents',
#  'Correspondence regarding the case K./J.',
#  'Correspondence while teaching in America 1968',
#  "Correspondence with 'Instituut voor Industriele Vormgeving' about the selection of items for the Utrecht spring and autumn fairs",
#  "Correspondence with 'Ministerie van Onderwijs, Kunsten en Wetenschappen' (Ministry of Education, Arts, and Science) about different subjects with reference to the commission 'Rijksadviescommissie Gebonden Kunsten'",
#  'Correspondence with Bernadine de Neeve',
#  'Correspondence with Binte Saetrang',
#  'Correspondence with C. Bachmann about the glass project EDESA, Swaziland',
#  'Correspondence with Charles Bray and Arjan Muijlwijk',
#  'Correspondence with Durk Valkema, Brian and Zahara Hughes, Titik Inn, and others',
#  'Correspondence with Frank L. Kulasiewicz',
#  'Correspondence with Geertje Huisman regarding a text about Vrij Glas',
#  'Correspondence with Harvey Littleton and with Gybson Byrd, on behalf of the Department of Art of the University of Wisconsin',
#  'Correspondence with Ingeborg Lundin, Luzia Hartsuyker, and others',
#  'Correspondence with Jaroslava Brychtova and Stanislav Libensky, 1972-1981',
#  'Correspondence with Jim Wright, Stone Barber and Bernie Marek; contains passport photos',
#  'Correspondence with Jon Andersson, West Surrey College of Art & Design',
#  'Correspondence with Kunstmuseum DÃ¼sseldorf',
#  'Correspondence with Maurine Littleton, Maurine Littleton Gallery, Washington D.C.',
#  'Correspondence with Michael Boylen',
#  'Correspondence with Mr. Moon, Carlisle College of Art & Design, about his visit to the Netherlands',
#  'Correspondence with Rajko Georgiev Rajkov, Bulgaria, 1970-1971',
#  'Correspondence with Rob van den Doel regarding technical questions',
#  'Correspondence with Roman Bartkiw, Georgian College of Applied Arts and Technology, Ontario, Canada',
#  'Correspondence with Simon Pearce; contains a postcard',
#  'Correspondence with Takako Sano',
#  'Correspondence with The Corning Museum of Glass',
#  'Correspondence with Veronique Valkema, Durk Valkema, Milos Zahrad, Ingeborg Lundin',
#  "Correspondence with Win Korink, chairman 'Vereninging van Vrienden van Modern Glas'",
#  'Correspondence with Yvonne Brunhammer, curator MusÃ©e des Arts DÃ©coratifs, Paris',
#  'Correspondence with former students, mostly private',
#  'Correspondence with members of various ceramics organisations',
#  'Correspondence with the Ministry OCW (Education, Culture and Science) asking Sybren Valkema to advise on a purchase of glass',
#  'Correspondence with the Pilchuck Glass School concerning the International Council',
#  'Correspondence with the Victoria & Albert Museum about the purchase of various glass objects',
#  "Correspondence with the editors of 'Lexicon Moderne Nederlandse Glaskunst 1900-1992'",
#  'Correspondence with the editors of the publications Glass Studio and Glass Art Magazine',
#  'Correspondence with various friends and acquaintances mainly about glass, glass techniques, and artistry',
#  "Correspondence, editorial office 'Goed Wonen' magazine",
#  'Correspondence, partly chronological',
#  "Course: 'Bedrijfsorganisatie van chefs'",
#  'Critique on the coding system school schedule vocational education',
#  "Critiques and lesson annotations 'Glasschool Leerdam'; also contains photographs of cold worked glass windows",
#  "Cultuurprijs' and 'Aanmoedigingsprijs', Hilversum",
#  "Cutting about W. Kandinsky in the Kunstzaal Oldenzeel Rotterdam in 'De Kunst: Een Algemeen GeÃ¯llustreerd en Artistiek Weekblad'",
#  'Danish glass studios and glass factories',
#  "De Leerdamse Glasindustrie'",
#  'De Vier Linden, Asperen, 2-30 August 1986',
#  "De Werkgroep Glas aan de Rietveld Academie in Amsterdam algemeen 1'",
#  'December 1938, part 2',
#  'Decoration techniques for ceramics',
#  "Dekselpotten & Dozen' in Het Kapelhuis, Amersfoort, 6 April - 8 May 1974",
#  "Der Glasschmelzer' (Part 1), 1928",
#  'Design drawing for a cut and engraved window depicting glassblowers',
#  'Design drawing for glass vitrines in a building at Klaaskampen 6, Laren, designed in cooperation with Architectenburo J.P. Roselaar',
#  'Design drawing of a clock with workers in an industrial setting, in a passe-partous, signed SV',
#  'Design drawing, possibly for a stencil',
#  'Design drawings and building plans of the house in Crailoo, Blaricum',
#  "Design drawings and sketches for glass windows with human figures, possibly used as exercise by pupils at the 'Glasschool Leerdam'",
#  'Design drawings for Unica by Sybren Valkema',
#  'Design drawings for series Palma and Stapelservies',
#  'Design drawings for textile',
#  "Design drawings for the series 'Structuur', with separate notes",
#  "Design drawings of zodiac signs, used as exercise by pupils at 'Glasschool Leerdam'",
#  'Design drawings: bottles for the distillery Wijnand Fockink',
#  "Design for a composition placed in 'Het Zonnehuis', Castricum",
#  "Design for a glass window with glassblowers, used as exercise by pupils; marked 'R73'",
#  'Design for a mirror, used as exercise by pupils',
#  'Design sketches and drawings for Unica and Serica',
#  'Design sketches and drawings for drinking glasses; The series Palma; The series Compact',
#  'Design sketches and drawings for special hand tools to make the series Palma',
#  'Design, a sun, for Het Zonnehuis, Castricum',
#  "Designs for windows including a commemorative window for 'Snelwegerfabriek Olland'",
#  "Designs in various weaving techniques submitted to the 'Nederlands Dessinbureau'",
#  "Deutsche Glastechnische Geselschaft', received documents",
#  "Deux Artists Verriers de Hollande' Galerie Transparence, Brussels, 17 September-21 October 1989",
#  "Diary records 'Glas: Gerrit Rietveld Academie v.a Maart 1969-1970'",
#  'Diary records about the construction of the new academy building, two notebooks',
#  "Document defining the goal and purpose of the 'Glasschool Leerdamâ€™; list of exhibited work at the exhibition 'Mensen en glas' Leerdam 1915-1981, Zonnehof Amersfoort; Lecture Rijksmuseum 1975",
#  'Documentation about Danish glass, including Holmegaard',
#  'Documentation about Finish glass, including Iittala',
#  'Documentation about Norwegian glass',
#  'Documentation about Swedish glass, including Kosta Boda',
#  'Documentation about Swedish glass, including Orrefors',
#  'Documentation about ceramics design and De Porceleyne Fles',
#  'Documentation about electric ceramics kilns, including design sketches and drawings',
#  "Documentation about exhibitions, including 'De Ploeg'",
#  'Documentation about flat glass',
#  'Documentation about glass adhesives',
#  'Documentation about various national and international glass exhibitions',
#  'Documentation and notes about aluminum titanate (Al2TiO5)',
#  'Documentation and notes about building an electric oven',
#  'Documentation and notes about the construction of an electric glass furnace',
#  "Documentation concerning 'Leerdam als glasstad'",
#  'Documentation from various companies on gas burners, parts and related tools',
#  'Documentation received from Marvin Lipofsky about glassmaking, including reports from glass symposia, and biographies',
#  'Documentation regarding glass and art history',
#  'Documents about acceding as member',
#  'Documents about monumental assignments (glass windows)',
#  'Documents about publications and exhibitions featuring work by Sybren Valkema',
#  'Documents about the appointment as drawing teacher at various schools',
#  'Documents about the design and the production of an ornamental curtain for the theatre in Leerdam',
#  "Documents about the design of glass objects for the divisions 'Product ontwikkeling' (Product development) and sales",
#  'Documents about the foundation of Stichting Glaskunst Nederland, and Art Glass Centre Glascentrum Schalkwijk',
#  'Documents about the participation in London in June 1965 as Dutch delegate',
#  'Documents about various exhibitions in which Sybren Valkema participated',
#  'Documents and notes pertaining to the Pattern Design lessons at the Gerrit Rietveld Academie',
#  'Documents concerning the Exhibition design curriculum at the IvKNO',
#  'Documents concerning the Gerrit Rietveld Academie',
#  "Documents pertaining to RIKA 'Centrum van een nieuwe glasvormgeving te Mechelen'",
#  "Documents pertaining to exhibitions by the 'Werkgroep Glas'",
#  "Documents pertaining to the 'Glasschool Leerdam' including the 'Herhalingscursus' (Repetition course) in 1952. (Pre-) history of 'Palma' stemware and 'Compact' stacked drinking glasses; Final exam 'GLM' course",
#  "Documents pertaining to the formation of the 'Glasvormcentrum Leerdam' in 1968",
#  'Documents pertaining to the history of IvKNO',
#  "Documents pertaining to the making of glass instruments; lecture 'Glasvorming in the kunst' by Sybren Valkema presented at a symposium organised by the 'Stichting Glastechniek', 18 September 1976, Eindhoven",
#  'Documents pertaining to the second congress about art education in Belgrade, Yugoslavia, May 1970, organised by AIAP',
#  'Documents received regarding an art commission adjacent to Zomerkade, Huizen',
#  "Documents referring to 'Vereniging van Vrienden van Modern Glas'",
#  "Documents referring to a column in the bulletin of 'Vereniging van Vrienden van Modern Glas' explaining the term 'porst' and 'klots'",
#  "Documents referring to the founding of 'Vereniging van Vrienden van Modern Glas'",
#  'Documents referring to trips to Belgrade (Belgrado, Yugoslavia) and Thessaloniki (Greece) visiting art and craft schools',
#  'Documents regarding a trip to Copenhagen, Denmark',
#  'Documents regarding a visit to art schools in Stockholm, 7-11 April 1965',
#  'Documents regarding an article by Yvon Coffeng',
#  "Documents regarding participation in the exhibition 'Door en Door Modern' in 'Ambachts- en Baljuwhuis' in Voorschoten",
#  'Documents regarding the Stichting Andries de Potter: Nationaal Museum voor de Hedendaagse Keramiek',
#  "Documents regarding the formation of 'Stichting Presentatie Jonge Kunstenaars' (a foundation presenting young artists) for which talks were held with Sybren Valkema, and others",
#  'Documents with reference to The Great California Glass Symposium',
#  "Documents with reference to a theatre play written and directed by Sybren Valkema performed by the pupils at the 'Glasschool Leerdam' in 'De Kunstmin' in Leerdam",
#  'Documents with reference to biographies about Sybren Valkema for publications',
#  'Documents with reference to designs for tableware, including Rumba and Gilde by A.D. Copier',
#  'Documents with reference to guest lectures about Polish glass',
#  'Documents with reference to management structure reform at the Gerrit Rietveld Academie',
#  'Documents with reference to spending cuts on art education, including documents of the taskforce partial education and the Lochemse taskforce',
#  'Documents with reference to superannuation schemes for teacher at the Gerrit Rietveld Academie',
#  'Documents with reference to the appointment as (drawing) teacher at various schools and academies',
#  "Documents with reference to the award 'Vriendenprijs' by the 'Vereniging van Vrienden van Modern Glas', their first 'Vriendenprijs' was awarded to Sybren Valkema in 1987 for his role as artist/pioneer studio glass/founder Glass department Gerrit Rietveld Academie",
#  "Documents with reference to the chronicle 'Werkgroep Glas1969-1979'; annual reports",
#  'Documents with reference to the conference in London, June 1965',
#  'Documents with reference to the contact with LASALLE College of the Arts, Singapore, about Glass Technology Education',
#  "Documents with reference to the design and the production of the glass panels 'Domo' in Beilen",
#  'Documents with reference to the establishment of the Glasvormcentrum Leerdam',
#  "Documents with reference to the exhibition 'L'Autour d'une rencontre' 26 January-18 February 1979",
#  "Documents with reference to the final exam 'Dagopleiding' 1973",
#  'Documents with reference to the glass lexicon',
#  'Documents with reference to the layout of the glass lab and bronze casting workshop',
#  'Documents with reference to the pronouncement and the effect of the art policy of the Blaricum municipality where Sybren Valkema was engaged as advisor',
#  "Documents with reference to the publication of texts describing Sybren Valkema's personal life",
#  "Documents with referrence to a forthcoming publication entitled 'Gebruiksvoorwerpen in glas' (Utilitarian glass)",
#  'Documents with regards to exchange opportunities for students at the Gerrit Rietveld Academie and Stourbridge College of Art',
#  'Documents with regards to the invitation to be Artist-in-Residence at the Pilchuck Glass School, together with Anna Carlgren and Durk Valkema, Juli 5-24, 1987',
#  'Draft folder retrospective exhibition, Singer Museum, Laren',
#  "Draft letter, written on behalf of Sybren Valkema, to the Glasfabriek Leerdam' about the participation in an exhibition in the showroom at Rokin 56 in Amsterdam",
#  'Drawing and painting assignments completed by the pupils, Van Keulen, Jansen, Kennedy and others',
#  "Drawing and painting assignments executed by the pupils Van Stek, D. de Leeuw, P.W. Vermeer, Den Hartog, W. Bel, G. Thomassen and Keulen in folder 'Krabbels houtskool e.d. van Steek oct. '45' (Doodles charcoal etc. Van Steek October 1945)",
#  'Drawing and painting assignments, not signed, presumably completed by various pupils',
#  "Drawing assignment 'Actieve compositie' (Active composition), signed Heesen",
#  'Drawing in charcoal, signed Diedericks',
#  'Drawing of a falconer on tracing paper, used as exercise by pupils',
#  "Drawing pad signed 'VALKEMA' with drawings pertaining to various glassmaking techniques",
#  'Drawing pad with sketches and notes regarding glass objects',
#  'Drawing, possibly design for textile',
#  'Drawings and sketches for Leerdam Unica and Serica',
#  'Drawings by the pupils Wim van Stek and Willem Heesen',
#  'Drawings for Unica',
#  'Drawings in chalk and paint',
#  'Drawings of animal figures in ink by pupils, signed J. Kennedy 1943 and D. Vermeer',
#  'Drawings of architectural details of the Notre Dame and Arras HÃ´tel de Ville in Paris',
#  'Drawings of cupboards, one depiction is signed by the pupil W. Versteeg',
#  "Drawings of fantasy figures, presumably by Sybren Valkema's pupils",
#  'Drawings of the Judgement of Paris, signed Heesen, and other images',
#  'Drawings; letters and notes',
#  "Early history of lampwork' by Rosemarie Lierke, a report",
#  'Eisch, Erwin',
#  'Electricity',
#  "European Studio Glass '82', Galerie Bellefontaine, Lausanne, 2 December 1982-19 February 1983",
#  "Exhibition 'Beeld-en-Wei', organised by the 'Oranje Vereniging' in Galerie de Vlierhoeve, Blaricum, 19-28 August 1988",
#  "Exhibition 'Duitse en Nederlandse vormgeving, TriÃ«nnale 1981'",
#  "Exhibition 'Glas', Nationaal Glasmuseum Leerdam",
#  "Exhibition 'Hand en Machine', organised by the 'GKf, Stedelijk Museum and the Milano Triennial",
#  "Exhibition 'Hedendaagse Nederlandse Glaskunst', De Reehorst, Ede, 22 November-8 December 1980",
#  "Exhibition 'Hollandische GlaskÃ¼nstler Heute', Glasmuseum Wertheim, 1 April-31 July 1981",
#  "Exhibition 'Leerdam Unica'",
#  "Exhibition 'Leerdam Unica', Kunstmuseum DÃ¼sseldorf 13 May-26 June 1977 'Leerdam Unica', Museum Boijmans Van Beuningen, Rotterdam 23 July-18 September 1977",
#  "Exhibition 'Mensen en glas: Leerdam 1915-1981', De Zonnehof, Amersfoort",
#  "Exhibition 'Nederlandse hedendaagse glaskunst'",
#  "Exhibition 'Neue arbeiten aus Holland', Galerie Ingrid Mensendiek, DÃ¼sseldorf, 11 November 1980-January 1981",
#  "Exhibition 'Objecten van glas en ceramiek uit Tsjechoslowakije' Museum Boijmans Van Beuningen, Rotterdam 1970",
#  "Exhibition 'Pioniere der Glaskunst'",
#  "Exhibition 'Sculptures et volumes de verre', MusÃ©e ChÃ¢teau d'Annecy, 28 June-8 October 1980",
#  "Exhibition 'Spel van glas en licht' in Bergeyk",
#  "Exhibition 'Sybren Valkema in Leerdam', Singer Museum, Laren, and Van de Brink Galerij",
#  "Exhibition 'Sybren Valkema in Leerdam, 75 jaar'",
#  "Exhibition 'Vrij Glas', De Vaart, Hilversum, August 1977",
#  "Exhibition 'Vrij Glas', GSA, Hilversum",
#  "Exhibition 'Vrij Glas', Zienagoog, Zaandam, August 1979",
#  'Exhibition Galerie Fischer, Augsburg',
#  'Exhibition Sybren Valkema Vrij Glas, Galerie Inart, Amsterdam, 24 November-31 December 1983',
#  'Exhibition Sybren Valkema Vrij Glas, Singer Museum, Laren 17 November-15 December 1991',
#  'Exhibition Sybren Valkema Vrij Glas, Singer Museum, Laren, 14 December 1986-18 January 1987',
#  'Exhibition Vrij Glas',
#  "Exhibition about the 'Werkgroep Glas' in the Nationaal Glasmuseum, Leerdam",
#  'Exhibition at Kunst & Keramiek, Deventer, 7 April-4 May 1991',
#  "Exhibition by Professor Harvey Littleton's first glass students in Museum Boijmans Van Beuningen, Rotterdam",
#  'Exhibition celebrating De Oude Horn 10th jubilee, organised by Stichting 1000Â° C, 26 January-6 March 1988',
#  'Exhibition during the World Crafts Council, Toronto, Canada, 9-15 June 1974',
#  "Exhibition in 'Kunstzaal Scherft' The Hague showing work by Paul Citroen and W.J. Rozendaal, with invitation to the exhibition",
#  'Exhibition in AMC Academisch Medisch Center, Amsterdam, organised by Galerie De Vier Linden, 15 June-30 July 1992',
#  'Exhibition in Gemeentehuis, Laren, 20 March-29 April 1989',
#  'Exhibition in Singapore, organised by the Ikebana Society, 18-20 November 1988',
#  "Exhibition in the 'Stichting Goed Wonen' showroom about the drinking glass",
#  'Exhibition in the Lukas Hospital, Apeldoorn, 15 February-13 March 1988',
#  'Exhibition in the St. Elisabeth Ziekenhuis, Amersfoort, 26 February-16 April 1987',
#  "Exhibition posters and artists' brochures",
#  'Exhibition, Essener Glasgalerie, Essen, 22 March-30 April 1981',
#  'Exhibitions in Galerie Het Kapelhuis, Amersfoort',
#  'Exhibitions in Keramisch Werkcentrum Heusden',
#  'Exhibitions in the Nationaal Glasmuseum, Leerdam',
#  'Exhibitions in the Soviet Union and the Netherlands showing work by Russian artists',
#  'Exhibitions with work by Gerhard Schechinger and Renato Santarossa in Glasmuseum Wertheim, Galerie Nanky de Vreeze',
#  'Exhibitions with work by the Norwegian designer Benny Motzfeldt, including De Zonnehof, Amersfoort',
#  "Exhibiton 'Pioniere der Glasbewegung', Galerie SM, Frankfurt am Main, 28 January- 21 February 1981",
#  'Extensive report from the First World Congress of Craftsmen',
#  'Extract from the population registry and secondary teaching certificate',
#  'Fall (November) 1939, part 3',
#  "Fashion project by G. vd. Oever, dated 3 May 1948, separate notes on 'Costuumkunde'",
#  "Fathers and sons' The Glass Art Gallery, Toronto, 19 July-13 August 1983",
#  'February 1937, part 2',
#  'February 1940, part 4',
#  'Febuary 1939, part 2',
#  'Female nude, in chalk',
#  'Female standing beside a curtain',
#  'Figure drawings in various techniques',
#  "Final exam 'Dagopleiding' 1973",
#  "Final exam 'Dagopleiding' 1974",
#  "Final exam 'Glasschool Leerdam'",
#  'Final exam exhibition in Museum Fodor Amsterdam',
#  "Final exams 'dagopleiding voor Beeldende Kunst en Vormgeving'",
#  'Firing notebook, with firing schedules and recipes',
#  'First International Glass Symposium, Museum Bellerive, Zurich, 4-9 June 1972',
#  'First World Congress of Craftsmen in New York, 8-19 June 1964',
#  "Five notebooks pertaining to various courses at the 'Glasschool Leerdam' including cold working classes",
#  "Five notebooks with lesson annotations pertaining to various courses at the 'Glasschool Leerdam'",
#  'Five phototypes of design drawings with birds, kamels, boats, for cold worked panels, Glasschool Leerdam or Glasfabriek Leerdam',
#  'Flower still lifes in pencil and watercolour',
#  'Flue gases, insulation, heat theory and furnaces, including furnace construction, electric ovens, annealers',
#  "Folder ' Filmfestspiele Berlin 1958' with notes, lecture' Glas' in Groningen",
#  "Folder 'Lesaantekeningen Glasschool Leerdam' (Lesson annotations 'Glasschool Leerdam')Contains separate notes",
#  'Folder Nederlands Textielmuseum',
#  'Folder with form studies for drinking glasses',
#  'Folder with notes about the series Palma',
#  'Folgering, Mieke',
#  'Fontein, Yvonne',
#  'French glass, mainly brochures',
#  'Frijns, Bert',
#  'Furnace construction',
#  'Furnace technology',
#  'Furnaces (black and white), annotated by Klaas Laansma after consultations with Durk Valkema',
#  'GLASS, Written and Compiled by Mr. Robert Held, Sheridan College, Mississauga, Ontario',
#  'GSA Genootschap voor Samenwerkende Ambachtskunstenaars, Hilversum',
#  'GSA Kunstzaal, Hilversum, 7 April - 1 May 1972',
#  'GSA, received letters as board member',
#  'Galerie 1632, Zaltbommel, 14 Oktober-4 December 1988',
#  'Galerie Acanthus, Maartensdijk, 17 October-22 November 1987',
#  'Galerie Art-Choque, Velp',
#  'Galerie Daniel Sarver, Paris, 15 September-25 October 1981',
#  'Galerie De Beerenburght, Eck en Wiel',
#  'Galerie De Beerenburght, Eck en Wiel, 5 May-4 June 1984',
#  'Galerie De Saveur, Ulestraten',
#  'Galerie Gooijer Fine Art, Doesburg, 24 October-21 November 1993',
#  'Galerie Het Glashuis, Alkmaar',
#  'Galerie Inart, Amsterdam',
#  'Galerie L',
#  'Galerie L, Hamburg, 26 October - 1 February 1973',
#  'Galerie Mat, Amsterdam, 26 April-23 May 1990',
#  'Galerie Rob van den Doel, The Hague',
#  'Galerie Rob van den Doel, The Hague, 24 July-8 August 1993',
#  'Galerie Slotine-Perkowsky, Le Havre',
#  'Gemeentehuis Bloemendaal, 13 September-4 October 1986',
#  'Gerrit Rietveld Academie curriculum with notes about student statistics',
#  'Gerrit Rietveld Academie, annual report 1979-1980',
#  'Gerrit Rietveld Academie, annual reports and final exams',
#  "Gianni Toso Maestro d'Arte Vetraria Workshop, California College of Arts and Crafts",
#  "Glas - Van drinkbeker tot Kunstobject', Museum voor Kunstambachten Sterckshof, Antwerpen-Deurne, 15 June-21 October 1990",
#  'Glas Galerie Arti-Choque, Velp',
#  'Glas Galerie, Lucerne',
#  "Glas Heute: Kunst oder Handwerk?', Ludwigshafen",
#  "Glas en Keramiek', a course by 'Stichting Vakexamen Glas en Keramiek', The Hague",
#  "Glas oud / nieuw'",
#  "Glas unserer Zeit', Frauenau, Internationsl symposium 20-22 May 1982",
#  "Glas' Kasteel Dussen, Land van Heusden en Altena, 4-19 February 1984",
#  "Glas' exhibition and catalogue Nationaal Glasmuseum Leerdam",
#  "Glas', 't Achterhoes, Roden, organised by Culturele Raad Roden, 9-24 November 1985",
#  "Glas, Van Drinkbeker tot Kunstobject', Provinciaal Museum Sterckshof, Deurne-Antwerp",
#  "Glas-Metamorphosen, 40 artistes verriers contemporains', Bahnhof Rolandseck, organised by Centre du verre du MusÃ©e des Arts dÃ©coratifs and Corning France, 30 April-5 May 1988",
#  "Glasblazerij 'De Oude Horn', Willem Heesen, Bernard Heesen",
#  'Glasgalerie Douwes Dekker, Utrecht',
#  'Glaskunst 81, Kassel, 3 September-18 October 1981',
#  "Glaskunst', Museum Dit is in Bethlehem, Gorinchem, 23 January-13 March 1988",
#  'Glasmuseet Ebeltoft',
#  "Glaspreis Bayerischer Wald'",
#  "Glass '84 in Japan: Talking to the World, Odakyu Grand Gallery, Shinjuku, Tokyo, 14-26 September 1984",
#  'Glass School Zwiesel, 1970; Memorial monument, 1968; Glasfabriek Leerdam, 1965 (negatives)',
#  'Glass Workshop and lecture during the World Crafts Council, Wien, 25 July-1 August 1980',
#  'Glass Workshop during the World Crafts Council, Kyoto, Japan, 9-15 September 1978',
#  'Glass congress and ceramics exhibition, Prague',
#  "Glass course: 'OriÃ«ntatiecursus Glas, Chemie van het glas' by Ir. S.C. Rademaker reviewed by Dr. Ir. J. Cornelissen",
#  'Glass course: Cursus Glas, Fysische Eigenschappen, A.L. Zijlstra',
#  'Glass engraving',
#  'Glass etching',
#  'Glass exhibition, Museum Boijmans Van Beuningen, Rotterdam',
#  "Glass fabrication assignments: booklet 'Leerdam Glas' (not signed); booklet 'Glass' by J. Kennedy, April 1944; two linoleum prints by J. Gruiters, in a passe-partout",
#  'Glass furnace "Anna"',
#  'Glass furnace "Anna" from September 1985, 1986-1987',
#  'Glass history with technical explanations, including paper-weights with monograms and decoration techniques',
#  "Glass manifestation '1450Â°C', Het Zeister Slot",
#  'Glass objects and windows designed by Floris Meydam',
#  'Glass schools in America (Pilchuck and Penland) and France (Sars-Poteries)',
#  'Glass schools in America (Pilchuck and Penland) including programmes',
#  'Glass window (black and white photographs)',
#  "Glass, werkboek 2'",
#  'Glassblower at work (black and white photograph), mounted on cardboard',
#  "Glasschool Leerdam' complete minutes since the charter meeting 2 February 1943; minutes of the teachers' meetings until 21 February 1950; curricula and syllabi until 19 December 1950; minutes and documents regarding a course in 1950-1951",
#  "Glasschool Leerdam' exhibition in the Stedelijk Museum",
#  "Glasschool Leerdam', two design drawings for cut glass panels with birds and ornamentations",
#  'Glasstudio Franzensbad, Baden b. Wien',
#  "Grant application 'Ministry Welzijn, Volksgezondheid en Cultuur'",
#  'Grebnickova, Stanislava',
#  'Grisaille, Enamel, Printable emulsion, Silk screen',
#  'Groot, Mieke',
#  "Group exhibition 'Glas: geblazen, geslepen, geÃ«tst, gegoten', Galerie Het Kapelhuis, Amersfoort 16 October-10 November 1976",
#  'Guest professor, University of Wisconsin 1968',
#  'Guest teacher National College of Art and Design, Dublin, 24-30 March 1984',
#  "Haagse Academie Nieuwsbrief 'De Hanekraai', handmade",
#  "Haagse Academie Revue's' with playwrightsâ€™ scripts for theatrical performances and designs for textbooks; also contains documents regarding the 'Haagsche Academieclub'",
#  'Harbinson Fineblit, Shirley',
#  "Hedendaagse Glaskunst in Nederland', Galerie Weert, 6 November-5 December 1983",
#  "Hedendaagse Nederlandse Glaskunst', organised by Edese Kunststichting, Ede, 13 December 1986-10 January 1987",
#  'Hedendaagse Nederlandse Glaskunst, Galerie Beelen, The Hague',
#  'Heidi Schneider Galerie, Horgen, Switzerland',
#  'Herder-Verwey, Kea de',
#  'Herman, Sam',
#  'Het Zonnehuis Castricum',
#  "Het kleine oventje vanaf 1962'",
#  'High Velocity Burners and Tempest Burners',
#  'Holmerud, Hasse',
#  'I',
#  'IGS Interglass Symposium Novy Bor 1988',
#  'II',
#  'III',
#  'IV',
#  'Illustrated furnace construction, text in Czech',
#  "Illustrated poster 'Van twee conincskinderen' (After two monarchs' children) signed V. Stek",
#  "Information about 'diamant-gravurrÃ¤dschen', including a drawing of a Czech lathe for copper engraving, instructions in Czech",
#  "Information folder by 'Institut Superieur de formation a l'art du Verre de Haute-Normandie'",
#  'Information for visual artists about State funding and acquisitions',
#  'Information for visual artists about regional and local funding',
#  "Instituut voor IndustriÃ«le Vormgeving', Sikkens, and ICSID, newsletters",
#  'Instructions Personal Computer, batch calculations, batch analysis',
#  'Instructions cold work',
#  'Instructions on cutting, grinding and engraving',
#  'Interglass Symposium 1985, organised by Crystalex, Novy Bor, Czechoslovakia',
#  "International Colloquium 'Verre et Architecture', MusÃ©e du Verre, Sars-Poteries, 4-7 April 1984",
#  'International Glass Symposium Novy Bor Czechoslovakia',
#  'International Studio Glass Seminar, Skolen for Brugskunst, Copenhagen, 4-7 September 1975',
#  'Interview with Sybren Valkema; also contains documents about the final exam at IvKNO in 1952',
#  'Invitation to a graduation ceremony at Akademie voor IndustriÃ«le Vormgeving, Eindhoven',
#  'Invitation to the opening of the Gerrit Rietveld Academie',
#  'Invitations and newspaper clippings regarding exhibitions and glassware',
#  'Invitations for exhibitions by various artists',
#  'Invitations to exhibitions showing work by Sybren Valkema, 5 September - 4 November 1979',
#  'Invitations to exhibitions showing work by Sybren Valkema, Durk Valkema or Anna Carlgren',
#  'Invitations to receptions during the conference in London, June 1965',
#  "Invoices 'Werkgroep Glas'",
#  "Invoices for Unica made in the 'Glasvormcentrum' at the 'Glasfabriek Leerdam'",
#  'Invoices from various suppliers of parts for gas burners, including manuals',
#  'Items of unclear origin',
#  'Items, including books',
#  'James Carpenter',
#  'January 1939, part 3',
#  'January 1940, part 4',
#  'January 1940, part 6',
#  'Joel Myers',
#  "Jong Glas', Nationaal Glasmuseum, Leerdam, 28 April - 28 May 1978",
#  'Journal entries during the World Crafts Council, New York, 1964',
#  'July 1940',
#  'June 1937, part 3',
#  'June 1939, part 3',
#  'June 1939, part 5',
#  'KIO membership',
#  'KIO, GSA, ICSID, received documents from national and international organisations representing artists',
#  'KIO, received documents',
#  'Kallio, Hessu',
#  "Keramische Vormgeving' (Ceramics Design)",
#  "Keramische Vormgeving' (ceramics department) students' projects and papers",
#  "Kring 't Gooi van de Nederlandse Federatie van Beroepsverenigingen van kunstenaars'",
#  "Kroniek van een glasman' (Cronical of a glass man), 'Het Kleine Oventje', Werkgroep Glas, with notes",
#  "Kunst uit de regio', Galerie De Vonk, Bussum, 7-28 May 1983",
#  'Kunstengalerij Lochem, 26 February - 19 March 1977',
#  'Kunsthaus am Museum, Cologne',
#  'La Galleria, Frankfurt am Main',
#  "Landelijke Vereniging van Docenten bij het Beeldend Kunstonderwijs', received documents",
#  'Large format black and white photographs displaying the process of blowing glass, mounted for display',
#  "Le verre et le vin', Saint-Ã‰milion, 21 June-15 August 1984",
#  "Lecture 'Glas in de bouwkunst', with notes, 1960",
#  "Lecture 'Rol Leendert van der Linden'",
#  "Lecture 'Vrij Glas', Singer Museum, Laren, 1991, with notes and corrections",
#  'Lecture Galerie Rob van der Doel, Galerie Kuhler',
#  'Lecture Royal College of Art, London: Furnace devellopments [sic] at the Gerrit Rietveld Academie in Amsterdam; author: Durk Valkema',
#  "Lecture at the award ceremony in Museum Boijmans Van Beuningen where Leendert van der Linden was awarded the 'Vriendenprijs' by the Vereniging Vrienden Van Modern Glas",
#  "Lecture at the opening of the exhibition 'Vrij Glas - een overzicht' by Sybren Valkema, Singer Museum, Laren and a lecture at the opening of the exhibition 'Glas als beeldhouwkunst', by Koen Vanderstukken",
#  "Lecture by Sybren Valkema 'Glas als beeldend materiaal' (Glass as visual art medium)",
#  'Lecture for the students in Mechelen',
#  'Lecture glass symposium Museum Bellerive, Zuerich, informatie ekspositiecentrum "het zeister slot" [sic] by A.D. Copier',
#  'Lecture in Rouen',
#  'Lecture to teachers, secondary education, Amersfoort',
#  "Lecture, 8iÃ¨me CongrÃ¨s de l'Association Internationale des Arts Plastiques, London",
#  "Leer- en oefenboek voor nijverheidsscholen, 1e en 2e leerjaar' by J. Kamminga",
#  'Leerdam 1964-1965',
#  "Lesson annotations 'Ikonografie' (Iconography); loose pages",
#  "Lesson annotations 'Nieuwe Geschiedenis' (General Art History from the Renaissance) Contains separate notes about the structure of the course Glassblowing",
#  'Letter from Dirk de Leeuw confirming that Sybren Valkema is appointed teacher of Textile and Textile Design at the IvKNO, Amsterdam',
#  'Letter from James Grant',
#  "Letter from Stichting Glastechniek, notes preface Gloeiend Glas, notes lecture Werkgroep Glas 1969-1979-1982, article in Elsevier Select nr. 4 October 1984 'Glaskunst uit Leerdam'",
#  'Letter from an unknown person addressed to Durk Valkema, including an article about Sybren Valkema',
#  'Letter to the former student Lies Cosijn',
#  'Letters from family and friends addressed to Sybren and Veronique Valkema during their stay in Penland, North Carolina (USA) where Sybren was teaching at the Penland School of Crafts',
#  "Letters to 'Kristalunie Maastricht' and the 'Glasfabriek Leerdam' regarding tools",
#  'Letters to Veronique Valkema after the passing of Sybren Valkema',
#  'Letters where the students are invited to participate in exhibitions in various museums and galleries in Germany',
#  'Libensky, Stanislav and Brychtova, Jaroslava',
#  'Life size drawings by the pupil P. Vermeer using ink, pens and brushes',
#  'Lipofsky, Marvin',
#  'List available films and videos regarding glass',
#  'Lists of acquisitions in different disciplines',
#  "Lists of art works purchased by the commission 'Rijksadviescommissie Gebonden Kunsten'",
#  'Littleton, Harvey',
#  'Ljungar, Lena and Jesper Sødring',
#  'Loo, Bert van',
#  'Loose notes and a typescript with notes on art education in the USA 1968',
#  "Magazine 'Interieur' with an article by Karel Wasch",
#  "Magazine 'Svensk Form' containing an article about the 'Glass School', in Swedish",
#  "Magazine 'Vorm', including an article with the title 'Concurreren met vormgeving'",
#  'Malis, Jack',
#  "Manifestation 'Glas'86', Leerdam",
#  "Manifestation 'Monumentale kunst in Blaricum' (Monumental art in Blaricum), 11-12 September 1992",
#  'Manual and handwritten notes about how to operate different kilns',
#  "Manuscript 'Biografisch overzicht', with notes by Klaas Laansma",
#  'Marc Treib',
#  'March 1938, part 5',
#  'March 1939, part 4',
#  "Material with reference to the collaboration 'Jong Talent' and the 'Glasfabriek Leerdam'",
#  'Materials for furnace building',
#  'Meitner, Richard',
#  'Member of the Examencommissie Nijverheidsonderwijs (N.O.), 1951, (Examination board crafts education), received documents',
#  'Meurs, Josien van',
#  'Meydam, Floris (Floor)',
#  'Minutes and notes from the 4th meeting of the Werkgroep Goote Kunstonderwijs (Taskforce Art Education) 27-28 October 1966? Lochem',
#  'Minutes and notes in preperation for meetings with teachers, and meetings about the construction of the new academy building',
#  'Minutes from board meetings',
#  'Minutes from meetings',
#  "Minutes from meetings with the board of directors, department chairs, teachers, the Academy Council and the 'Vereniging Quellinus'",
#  'Mixing of colours in glass',
#  'Mosaic techniques, including stained glass',
#  'MusÃ©e des Beaux-Arts, Rouen, 21 June-15 August 1984',
#  'Muylwijk, Arjan',
#  "Nederlandse Vakgroep Keramisten', received documents regarding the membership",
#  "New Glass in the United States' 1982 by Tom Buechner 'L'Avenier de la Creation en Verrerie' by J. Moullier, including a list of participants",
#  'Newsletters and brochures, including Kosta Boda',
#  'Newspaper clippings about the Gerrit Rietveld Academie',
#  "Newspaper cutting 'Wij bezochten de Kunstnijverheidsschool te Amsterdam'",
#  'Newspaper cuttings and notes on art education in the Netherlands',
#  "NiederlÃ¤ndische Glaskunst', Glashaus GÃ¶ttingen, Munich, 21 April-1 August 1983",
#  "Nomades du Verre Barcelona' organised by Galerie H.D. Nick in the Centre del Vidre, Barcelona",
#  "Nordiskt Glas '81, symposium and exhibition, Finland",
#  'Notebook',
#  "Notebook ' Kunstgeschiedenis dictaten D.E.C. Leerdam 1 1944' (Art History Lecture Notes); contains separate notes",
#  "Notebook 'Cursus IvKNO 1946-1947; textile; weaving; fashion; including grades",
#  "Notebook 'Glasschool Leerdam 1947'",
#  "Notebook 'Kleuren' with notes about colour theory and separate documentation",
#  "Notebook 'Kunst Geschiedenis Iep Valkema 1931-'32 9e klas Vrije School'",
#  "Notebook 'Ned taal gram III' with notes about form and colour theory; also contains notes by (or about) pupils",
#  'Notebook Bauhaus Iep Valkema 1944, notebook Sequel Bauhaus 1930, notebook 18e-eeuwse glasgraveurs (18th century glass engravers)',
#  'Notebook IvKNO lessons and separate notes',
#  'Notebook on the subject colour theory, with separate notes and the schedule 1964-1965',
#  'Notebook pertaining to a trip to Paris in August 1938',
#  'Notebook with an opinion on art education in the Netherlands and notes on an AIAP congress (in Jugoslavia?)',
#  "Notebook with daily notes pertaining to the lessons at the 'leerschool'",
#  'Notebook with drawing exercises, contains separate notes',
#  'Notebook with notes about architecture and philosophy',
#  'Notebook with notes about daily activities and events at De Porceleyne Fles, Delft',
#  "Notebook with notes about the 'Oud-Indische Tijd'",
#  'Notebook with notes about the subject Physics',
#  'Notebook with notes from three lectures',
#  "Notebook with notes per grade pertaining to the lessons at the 'Dalton HBS' ; contains loose notes",
#  "Notebook with notes per grade pertaining to the lessons at the 'HBS' Raamstraat",
#  "Notebook with notes per grade pertaining to the lessons at the 'Maerlant-Lyceum' Bilderstraat",
#  'Notebook with notes per grade pertaining to the lessons at un unknown school',
#  "Notebook with the headings: 'Glasschool Leerdam 1943', 'Klein oventje 1964' (Small furnace 1964), 'Werkgroep Glas 1969'",
#  "Notebook; 'Avondond'",
#  'Notes Leerdam 1949 and 1964',
#  'Notes about graphic techniques, contains samples',
#  'Notes about materials for furnace building',
#  'Notes and correspondence with the publisher Gaade bv Amerongen',
#  "Notes and manuscripts based on interviews with Sybren Valkema, including Valkema's own corrections",
#  'Notes and report on visits to art education institutes in the USA in 1968 including the University of Wisconsin / Madison',
#  'Notes and typescripts regarding the biography in the book',
#  'Notes by Klaas Laansma',
#  'Notes concerning the move and inventory of the new building of the Gerrit Rietveld Academie',
#  'Notes for a guidance plan for visual art education in the Netherlands',
#  'Notes for an exhibition in Montreal 1967',
#  'Notes for minutes, 10th meeting of the taskforce, 1 October 1970, Lochem',
#  'Notes from a lecture referring to art education and visions on art education',
#  "Notes on 'workshops'",
#  'Notes on art education in USA 1968, and Vysoka skola Umelecko Prumyslova "UMPRUM" Prague',
#  'Notes on clay and glazing tests',
#  "Notes on glass techniques and recipes, including 'Kupfer rubin', and a mould recipe for kilncasting (Corning)",
#  'Notes on syllabi of national and international art education institutions',
#  'Notes on the structure of the education at the Washington University, St. Louis, Missouri and the Madison Technical College',
#  "Notes pertaining to the exam textile 'Warenkennis' 24 November 1958",
#  "Notes regarding the broadcast: Vorm en functie van sieraden', (Form and function of jewellery) Hans Appenzeller in an interview by Peter van Ingen (?), 28 December 1979",
#  'Notes with an opinion on art education',
#  'Notes, and a notebook pertaining to Art History',
#  'Notes, typescripts, bibliography, acknowledgements',
#  "Notes; list of exhibited objects; teaching materia; glass chemistry lesson; D.E.C. 'Glasschool Leerdam'",
#  'November 1937, part 4',
#  'November 1939',
#  'October 1936, part 1',
#  'Official documents USA 1968',
#  "Onderwijscommissie van de Vereniging van Akademies voor Beeldend Kunstonderwijs (VABK)'",
#  'Opening of Glasmuseet Ebeltoft, 27 June 1986',
#  'Opening of the Glasmuseum Frauenau, 6 May 1975',
#  "Opening speech Galerie Ingrid Mensendiek 1980, 'Glass Europe still has a Chance' by Jack Ink at the World Crafts Council Crafts tomorrow 1980 Wien Austria",
#  'Opening speech Tiel 1983',
#  "Opening speech exhibition 'Glasarchitecture' organised by Stichting Wonen, author: Chris Rehorst",
#  'Opening speech; text Bernardine de Neeve 1985',
#  'Orders of graphite from the company Schunk & Ebe GmbH, Giessen, Germany',
#  "Original syllabus 'School voor Glasversiering en veredeling'",
#  'Overview product design',
#  'Painted, 1935, or undated',
#  'Painting assignments, signed T. v. Dijk and Van Stek 1944',
#  'Paintings and form studies by the pupils E. v. Zanten, K.Gudde, G.J v. Steenis, C.G. v. Steenis',
#  'Paintings by the pupils E. van Zanten, Gudde[n?], Gerrit van W, G.J. v. Steenis and others',
#  'Paintings by the pupils Wim van Stek, Willem Heesen and others',
#  "Paper collage with the heading 'Kinderkolonies steuntâ€¦'",
#  'Part 1',
#  'Part 2',
#  'Part 3',
#  'Passports',
#  'Payroll statements',
#  'Photographs of sculptures by Mic Jonk and a final exam 1983',
#  'Porceleyne Fles Delft',
#  'Porceleyne Fles, catalogue',
#  'Postcards written by Veronique Valkema from Yugoslavia to her son Durk Valkema',
#  "Poster 'een expositie van glas en glastoepassingen in de bouw van 15 mei t/m 29 juni 1968', Bouwcentrum Rotterdam",
#  "Poster with the American flag with the description 'Help'",
#  'Poster, 10th jubilee Werkgroep Glas, the Gerrit Rietveld Academie',
#  'Posters on glass exhibitions',
#  "Premier Symposium du Verre Internationale en France', MusÃ©e du Verre, Sars-Poteries, April 1982",
#  "Preparation Syllabi 'D.E.C.'; notes, teaching material",
#  'Preparation for the AIAP congress about art education',
#  'Presentation drawing, watercolour, possibly for a mural or stage decoration',
#  "Press release 'Glaskunstenaar Sybren Valkema exposeert in Museum Van der Togt'",
#  'Printed textile, designed and executed by Sybren Valkema',
#  "Printer's proof, with notes",
#  "Project 'Projectie & Perspectief' by Rob Slooten",
#  'Provinciehuis Lelystad, 19 May-30 June 1993',
#  "Publication 'ChemiebÃ¼chlein des Glasschmelzers' by Eberhard Zschimmer, 1923",
#  "Publication 'Leerdam Unica' with an article by Helmut Ricke",
#  "Publication 'Rezeptbuch fÃ¼r die praktische Glasschmelz' door Wilhelm Schmidt, 1926",
#  "Publication 'Short guide to World Crafts: First World Congress of Craftsmen'",
#  'Publications and brochures by the Glasfabriek Leerdam',
#  'Publications including articles about the history of IvKNO',
#  "Pupils' grades and results, notes, and received documents",
#  'PÃ¢te de verre, including recipes for moulds',
#  'PÃ¶schl, Veronica',
#  "Questions and answers 'klasse 1', signed Valkema",
#  'Quotes and invoices',
#  'Raad voor de Kunst (Netherlands Arts Council)',
#  "Raakproblemen van Apellonius [sic]' (Problem of Apollonius)",
#  'Received and dispatched documents as member of the advisory commission',
#  'Received document from the Ministerie van Cultuur, Recreatie en Maatschappelijk werk, including an article by Th. Dobbelman',
#  'Received documentation from the World Crafts Council',
#  'Received documents',
#  'Received documents about Carlo Andreoli, mainly invitations for exhibitions',
#  'Received documents about an art commission adjacent to Zomerkade, Huizen',
#  'Received documents about the 1% art regulation',
#  'Received documents about the art acquisitions in 1992',
#  'Received documents about the art installation in a day-care centre',
#  'Received documents about the art installations in a fire brigade station in Huizen',
#  'Received documents about the preparation for an art commission adjacent to Zomerkade, Huizen',
#  "Received documents about work-meetings at the 'Glasfabriek Leerdam'; royalties 1952 and Newspaper clippings 1947",
#  'Received documents and separate notes about the structure of the education in different departments at art academies in the Netherlands',
#  'Received documents as board member',
#  "Received documents as chairman of the commission 'Rijksadviescommissie Gebonden Kunsten'",
#  "Received documents as chairman of the commission 'Rijksadviescommissie Gebonden Kunsten', with notes",
#  "Received documents as member of the commission 'Rijksadviescommissie Gebonden Kunsten', mainly minutes from meetings",
#  "Received documents as member of the commission 'Rijksadviescommissie Gebonden Kunsten', with notes",
#  "Received documents from 'Instituut voor IndustriÃ«le Vormgeving'",
#  "Received documents from 'Stichting Modern Glas' sent to the editorial commission of 'Lexicon Moderne Nederlandse Glaskunst 1900-1992'",
#  "Received documents from Bernadine de Neeve, 'ComitÃ© Bernadine de Neeve' and Pilchuck Glass School, and others",
#  "Received documents from COSA about the World Crafts Council's congresses",
#  'Received documents from Dominick Labino about glass techniques, including Egyptian sand-core, and photosensitive glass',
#  'Received documents from Elizabeth McClure',
#  'Received documents from GKf Gebonden Kunsten Federatie about participating in the First World Congress of Craftsmen in New York, 1964',
#  'Received documents from Greetje Huisman',
#  'Received documents from Jac Linssen',
#  'Received documents from Jamie Carpenter, Rhode Island School of Design, including pictures',
#  'Received documents from Jan Walgrave, Het Sterckshof Provinciaal museum voor kunstambachten, Deurne Antwerp',
#  'Received documents from Laborglas, Haarlem, supplier of Scientific glass, glassblowing tools and machines, sent to IvKNO',
#  'Received documents from Marvin Lipofsky, including the The Great California Glass Symposium',
#  'Received documents from students in different departments at the Gerrit Rietveld Academie',
#  "Received documents from the 'CoÃ¶rdinatie-Commissie Buitenlandse Tentoonstellingen Gebonden Kunsten'",
#  "Received documents from the 'Instituut voor IndustriÃ«le Vormgeving' about exhibitions",
#  'Received documents from the Academie voor Beeldende Kunsten, The Hague',
#  "Received documents from the Museum Skla Bizuterie with reference to the participation by the Gerrit Rietveld Academie in the 'Jablonec 71' International Costume Jewellery Exhibition",
#  'Received documents from the Penland School of Crafts',
#  "Received documents pertaining to various glass committees, founded by Klaas Laansma; also contains a letter from J. (Han) Feenstra 'De Suikerfabriek, Veldhoven' and press cuttings on exhibitions featuring work by Sybren Valkema",
#  'Received documents regarding the purchase of art work by Sybren Valkema',
#  'Received documents with reference to AIAP congress, Amsterdam, 9-11 October 1969',
#  'Received documents with reference to the Gerrit Rietveld Academie; invitations to final exam exhibitions',
#  'Received documents, and copies of despatched letters regarding the AIAP international conference about art education, London, 7-14 June 1965',
#  'Received documents, artist applications',
#  'Received documents, including material about a conference at the Northern Centre for Contemporary Art, Sunderland, 1984',
#  'Received documents, mainly brochures and posters from the Pilchuck Glass School',
#  'Received documents, predominantly artist applications',
#  'Received documents, with notes, received as examiner for craft education (N.O. Nijverheidsonderwijs) 1948 and 1949',
#  'Received invitations to national and international glass events, and brochures',
#  'Recipes Labino formula, RÃ¶tt glas (red glass, in Swedish), Peligot geel (a yellow)',
#  "Recipes Penland: technical documentation regarding pots for melting coloured glass; article about the furnace at General Glass Bellamystraat Amsterdam. Recipe Sandvik's glass. Technical documentation on raw materials regarding expansion coefficients; Article in 'Glasteknisk Tidskrift' about mathematical calculations in the hot shop",
#  'Recipes and calculations, instructions grinding lathe',
#  'Recipes and teaching material',
#  'Reclining female nude, in chalk',
#  'Refractory, insulation, burners, materials, raw materials, including gas suppliers, tools, cutting, adhesives',
#  'Reisinger, Barbara',
#  "Replacement and succession as teacher for the 'Werkgroep Glas' and deputy-director of the Gerrit Rietveld Academie",
#  "Report about 'Werkgroep Vormgeving Gobletterie, handbedrijf N.V. Koninklijke Nederlandsche Glasfabriek Leerdam' by F. Meydam",
#  'Report from the NCN and the AIAP congress, London, 6-10 March 1967',
#  "Report from the symposium 'Glas en Licht' HSK, Utrecht, 1988",
#  'Reports and correspondence regarding copyright infringement by the Kunstaardewerkfabriek De Gebroeder, Gouda, Case Bernadotte Georg Jensen and the Jeka-pitcher, De Ploeg, N.V. Mosa and De Gebroeder',
#  'Reports from various commissions at IvKNO about educational matters',
#  'Rhone-Poulenc',
#  'Robert Wilson',
#  'Rozengalerie, Amsterdam, 12 March-30 April 1983',
#  "Ruim 40 jaar Nederlands glas'",
#  'Safety in glass and ceramic studios by Charles Bray',
#  'Salary records and received announcements regarding the pension act 1922',
#  "Samenspel van keramiek, glas, metaal, textiel, natuursteen en hout met de architectuur', January 1964, with the article 'Spelen met Vuur', May 1964; 'Licht Versieren met Glas', December 1964; 'Keramiek en glas in Architectuur', nr 2 and 4, 1963",
#  'School assignments by Wybe Valkema about the glass factory in Leerdam',
#  'Scribbling pads',
#  'Scribbling pads with calculations and notes, contains separate notes',
#  "Seminar 'Creativity and professionalism', United Kingdom, 10-13 March 1975",
#  'Separate sketches, and three sketch books with individual sketches',
#  'September 1938, part 1',
#  'Silk screen',
#  'Singer Museum Laren',
#  'Singer Museum, Laren',
#  'Sketch for mould blown decoration',
#  'Sketch, design and working drawing for a glass window portraying Christ [at the Sea of Galilee?], presumably made by a pupil, not signed',
#  'Sketchbook',
#  'Sketchbook with notes, and sketches in ink and pencil',
#  "Sketches and designs used for pupils' experiments",
#  'Sketches and drawings for drinking glasses',
#  'Sketches and drawings for textile, three women in a seascape',
#  'Sketches and drawings of a ballet dancer',
#  'Sketches and drawings, various depictions and techniques',
#  'Sketches and drawings, with notes',
#  "Sketches and notes about a furnace in 'het hutje in het bos' (Valkema's own studio in Blaricum)",
#  'Sketches and notes for Leerdam Unica',
#  'Sketches and studies in charcoal depicting different images',
#  'Sketches for textile',
#  'Snabel-Floor, Lida',
#  'Speech by Sybren Valkema, award ceremony The Sybren Valkema Honorary Prize 1987',
#  'Spring 1939, part 2',
#  'Standing female nude',
#  'Stencil for a bowl or vase',
#  'Stencil or profile plate, the image is a portrait of a woman',
#  'Steuben, Corning, New York',
#  'Stichting Beeldende Kunst Kunstuitleen, Amsterdam',
#  'Still life drawings of interiors',
#  'Still lifes in watercolours',
#  'Still lifes, oil on linen',
#  'Stralen, Yvonne van',
#  'Streekmuseum De Groote SociÃ«teit, Tiel, 3 November-3 December 1983',
#  "Student critiques, mostly of the 'Werkgroep Glas'",
#  "Studio '40, The Hague, 14 November-31 December 1981",
#  "Studium Generale' Gerrit Rietveld Academie 7 March 1979 with Sybren Valkema",
#  'Summer exhibition, GSA Kunstzaal, Hilversum',
#  "Sybren Valkema's CV, biography and bibliography; also contains some lyrics",
#  "Syllabus 'Geschiedenis van het Glas' (Glass History)",
#  "Syllabus 'Kunstgeschiedenis - Middeleeuwen' (Art History - Middle Ages)",
#  "Syllabus 'Kunstgeschiedenis - Oudheid' (Art History - Ancient Times)",
#  "Syllabus 'Kunstgeschiedenis - Renaissance' (Art History - Renaissance)",
#  "Syllabus 'Schilderkunst 20e eeuw D.E.C.' (20th-Century Paintings 'D.E.C.')",
#  "Symposium 'Glas en Licht' (Glass and Light), Hogeschool voor de Kunsten, Utrecht, Lecture 9 April 1988",
#  "Symposium 'Working with hot glass', International Conference and Workshop, 5-10 September 1976, Royal College of Art, London",
#  'SÃ¼ssmuth-Glaskunst-Tage, organised by the SÃ¼ssmuth-Stiftung, Immenhausen, 16-21 July 1985',
#  'Talk Richard Meitner',
#  'Teaching at the Penland School of Crafts, North Carolina, fall 1986',
#  "Teaching material, 'Geschiedenis van het glas, van het jaar 0 tot 1948' (Glass History from the year 0 to 1948) and the first final exam at the 'Glasschool Leerdam' in May 1948",
#  'Teaching material, drafts, notes',
#  'Teaching material: Colour theory',
#  "Teaching material; Syllabus 'Algemene Kunstgeschiedenis' (General Art History); contains loose notes",
#  "Teaching material; Syllabus 'Beschavingsgeschiedenis' (History of Civilization)",
#  'Teaching notes arts and craft education 1947',
#  "Technical documentation about a 'Pyroclaaf' oven",
#  'Technical drawing of an oven',
#  'Technische Hogeschool Twente, Enschede',
#  'Temperature controllers',
#  'Tests or exams with questions and answers',
#  'Teunissen van Manen, Corina',
#  'Text by Yvon Coffeng about Sybren Valkema',
#  'Textile design for a curtain, possibly produced by F.D.M voor H. Hart, including instructions for the production',
#  'Textile designs for a cafÃ© or restaurant tapestry or carpet, including instructions for the production',
#  "Textile designs with the heading 'Motto DEC b3'",
#  'Texts by A.D. Copier, W. Heesen and F. Meydam about glassblowing and glass manufacturing processes, mounted for display',
#  "The Independent Glassblower'",
#  'The history of glass and glass beads',
#  "The history of the 'Werkgroep Glas', Gerrit Rietveld Academie 1964-1980",
#  'Thorgeirsdottir, Brunhildur',
#  'Three design drawings of bottles for Weinant Fokking',
#  "Three notebooks used for the school subject 'Geschiedenis van het glas' (Glass History)",
#  'Three sketches for decorated glass windows',
#  "Travelling exhibition 'Moderne Glas aus Amerika, Europa und Japan'",
#  "Travelling exhibition 'Textil och glas frÃ¥n Holland' organised by 'Bureau Beeldende Kunst Buitenland, Ministerie Van Cultuur, Recreatie en Maatschappelijk werk (CRM)'",
#  'Travelling exhibition Enmansglas: FrÃ¥n Kanada, USA, England, Holland, Danmark, Finland, Norge, Sverige',
#  "Travelling exhibition VRIJ GLAS with work by Sybren Valkema, Harvey Littleton, Erwin Eisch, Marvin Lipofsky, Sam Herman, and Harvey Littleton's first glass students, in Museum Boijmans Van Beuningen, Groninger Museum and Gemeentemuseum Arnhem",
#  "Tributes by colleagues and former students 'Collage voor Sybren'",
#  'Trulinos, Nikos',
#  "Tweede Distributie Stamkaart' ration card with loose ration stamps, found in 'Catalogus Nederlandse Beeldende Kunst, Rijksmuseum 1941'",
#  "Two design drawings for the layout of the exhibition showing pupils' work at the Stedelijk Museum in Amsterdam",
#  "Two notebooks pertaining to the course for cutters and the course for glassmakers at the 'Glasschool Leerdam'",
#  'Typescript "Lecture with slides International Glass Symposium Novy Bor October 1982", with notes',
#  "Typescript 'De betekenis van kleur in ceramiek' by Jet Sielcken, 1951, and a manuscript 'Kleurtoepassingen bij gebruiksaardewerk' by Francine Timmers, undated",
#  'Typescript lecture in Kyoto 1978, with notes',
#  "Typescripts on the history of the 'Glasschool Leerdam'",
#  'Typoscript \'Voorbereidende gedachte voor het ontstaan van "Compact" 1954\' by the Glasschool Leerdam and Stedelijk Museum, 5-28 September 1947',
#  'Uitnodigingen voor exposities met werk van Sybren Valkema',
#  'Undated',
#  'Unica and Serica documents and drawings',
#  'Unica by Sybren Valkema presented by the Dutch Prime Minister Van Agt to Zhao Ziyang during a state visit to China, 1980',
#  "UniversitÃ\xa0 Internazionale Dell'Arte Firenze-Venezia",
#  'V',
#  'VI',
#  'VII',
#  'VIII',
#  'Val Saint Lambert 1972',
#  'Valkema, Durk',
#  'Various ballet dancers',
#  'Various exhibitions at Galerie Het Glashuis, Alkmaar',
#  'Various glass design assignments completed by the pupils T. van Dijk, Verver, P.W. Vermeer, E. van Zanten and others',
#  'Various glass objects, and artists at work',
#  'Various recipes, theories, calculations and formulas',
#  'Various skeches and draft notation for glass, tools and sets',
#  "Various sketches for tableware; the 'Palma' series",
#  'Verberne, Daniel',
#  "Veronique and Sybren Valkema's draft testaments",
#  "Veronique and Sybren Valkema's testaments",
#  "Verre Contemporain en Europe', Galerie Paskine de Gignoux, Strasbourg, 1-31 December 1984",
#  "Verrerie Le Pontil', Dieulefit, June 1990",
#  'Verrerie de Biot',
#  'Vogel, Bart de',
#  'Walkey, Diane',
#  "Werkboek'",
#  "Werkgroep Glas' annual reports",
#  "Werkgroep Glas' critiques and schedules",
#  "Werkgroep Glas' organisation, planning and student critiques, year's courses 1977-1978 and 1978-1979",
#  'Westerlund, Birgitta',
#  'Willem Heesen, 4 black and white photographs of work designed by Willem Heesen',
#  'Winsen, Dok van',
#  'Wood or linoleum print on rice paper depicting a ship, in a passe-partout, signed FdL',
#  'Work on consignment Littleton Company Inc., Spruce Pine and Galerie Rob van den Doel, The Hague',
#  'Working drawings and cut-outs',
#  'Working drawings and volume calculations',
#  'World Expo 1958 in Brussels: design drawing for a dalle de verre window',
#  'Yvonne Brunhammer, MusÃ©e des Arts DÃ©coratifs, Centre du Verre, Paris',
#  'Zentralschweizer Glaspreis 1980, Lucerne, 13 August-26 September 1980, organised by Roberto Niederer, Hergiswiler Glas',
#  'Zweiter Coburger Glaspreis fÃ¼r Moderne Glasgestaltung in Europa, Kunstsammlungen der Veste Coburg, Coburg, 14 July-13 October 1985',
#  'Zynsky, Toots',
#  '[1938?], part 6',
#  "jan. '40 (deel 6)",
#  'â€˜Americans in Glassâ€™, Gemeentemuseum Arnhem']
